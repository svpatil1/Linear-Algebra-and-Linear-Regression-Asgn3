# %% [markdown]
# # Linear Algebra and Linear Regression
#
# ### 13th October 2015 Neil Lawrence
#
#
# ## Sum of Squares Error
#
# Last week we considered a cost function for minimization of the error. We considered items (films) and users and assumed that each movie rating, $y_{i,j}$ could be summarised by an inner product between a vector associated with the item, $\mathbf{v}_j$ and one associated with the user $
# \mathbf{u}_i$. We justified the inner product as a measure of similarity in the space of 'movie subjects', where both the users and the items lived, giving the analogy of a library.
#
# To make predictions we encouraged the similarity to be high if the movie rating was high using the quadratic error function,
# $$
# E_{i,j}(\mathbf{u}_i, \mathbf{v}_j) = \left(\mathbf{u}_i^\top \mathbf{v}_j - y_{i,j}\right)^2,
# $$
# which we then summed across all the observations to form the total error
# $$
# E(\mathbf{U}, \mathbf{V}) = \sum_{i,j}s_{i,j}\left(\mathbf{u}_i^\top \mathbf{v}_j - y_{i,j}\right)^2,
# $$
# where $s_{i,j}$ is an indicator variable which is set to 1 if the rating of movie $j$ by user $i$ is provided in our data set.
#
# This is known as a sum of squares error. Minimizing it was first proposed by [Legendre](http://en.wikipedia.org/wiki/Adrien-Marie_Legendre) in 1805. His book, which was on the orbit of comets, is available on google books, we can take a look at the relevant page by calling the code below.

# %%
import pods
pods.notebook.display_google_book(id='spcAAAAAMAAJ', page=72)
# Out:
# <iframe frameborder="0" scrolling="yes" style="border:0px" src="http://books.google.co.uk/books?id=spcAAAAAMAAJ&pg=PA72&output=embed", width=700 height=500></iframe>

# %% [markdown]
# Of course, the main text is in French, but the key part we are interested in can be roughly translated as
#
# "In most matters where we take measures data through observation, the most accurate results they can offer, it is almost always leads to a system of equations of the form
# $$E = a + bx + cy + fz + etc .$$
# where a, b, c, f etc are the known coefficients and  x , y, z etc are unknown and must be determined by the condition that the value of E is reduced, for each equation, to an amount or zero or very small."
#
# He continues
#
# "Of all the principles that we can offer for this item, I think it is not broader, more accurate, nor easier than the one we have used in previous research application, and that is to make the minimum sum of the squares of the errors. By this means, it is between the errors a kind of balance that prevents extreme to prevail, is very specific to make known the state of the closest to the truth system. The sum of the squares of the errors $E^2 + \left.E^\prime\right.^2 + \left.E^{\prime\prime}\right.^2 + etc$ being
# \begin{align*}   &(a + bx + cy + fz + etc)^2 \\
# + &(a^\prime + b^\prime x + c^\prime y + f^\prime z + etc ) ^2\\
# + &(a^{\prime\prime} + b^{\prime\prime}x  + c^{\prime\prime}y +  f^{\prime\prime}z + etc )^2 \\
# + & etc
# \end{align*}
# if we wanted a minimum, by varying x alone, we will have the equation ..."
#
# This is the earliest know printed version of the problem of least squares. The notation, however, is a little awkward for mordern eyes. In particular Legendre doesn't make use of the sum sign,
# $$
# \sum_{i=1}^3 z_i = z_1 + z_2 + z_3
# $$
# nor does he make use of the inner product.
#
# In our notation, if we were to do linear regression, we would need to subsititue:
# \begin{align*}
# a &\leftarrow y_1-c, \\ a^\prime &\leftarrow y_2-c,\\ a^{\prime\prime} &\leftarrow y_3 -c,\\
# \text{etc.}
# \end{align*}
# to introduce the data observations $\{y_i\}_{i=1}^{n}$ alongside $c$, the offset. We would then introduce the input locations
# \begin{align*}
# b & \leftarrow x_1,\\
# b^\prime & \leftarrow x_2,\\
# b^{\prime\prime} & \leftarrow x_3\\
# \text{etc.}
# \end{align*}
# and finally the gradient of the function
# $$x \leftarrow -m.$$
# The remaining coefficients ($c$ and $f$) would then be zero. That would give us
# \begin{align*}   &(y_1 - (mx_1+c))^2 \\
# + &(y_2 -(mx_2 + c))^2\\
# + &(y_3 -(mx_3 + c))^2 \\
# + & \text{etc.}
# \end{align*}
# which we would write in the modern notation for sums as
# $$
# \sum_{i=1}^n (y_i-(mx_i + c))^2
# $$
# which is recognised as the sum of squares error for a linear regression.
#
# This shows the advantage of modern [summation operator](http://en.wikipedia.org/wiki/Summation), $\sum$,  in keeping our mathematical notation compact. Whilst it may look more complicated the first time you see it, understanding the mathematical rules that go around it, allows us to go much further with the notation.
#
# Inner products (or [dot products](http://en.wikipedia.org/wiki/Dot_product)) are similar. They allow us to write
# $$
# \sum_{i=1}^q u_i v_i
# $$
# in a more compact notation,
# $
# \mathbf{u}\cdot\mathbf{v}.
# $
#
# Here we are using bold face to represent vectors, and we assume that the individual elements of a vector $\mathbf{z}$ are given as a series of scalars
# $$
# \mathbf{z} = \begin{bmatrix} z_1\\ z_2\\ \vdots\\ z_n \end{bmatrix}
# $$
# which are each indexed by their position in the vector.
#
# ## Linear Algebra
#
# Linear algebra provides a very similar role, when we introduce [linear algebra](http://en.wikipedia.org/wiki/Linear_algebra), it is because we are faced with a large number of addition and multiplication operations. These operations need to be done together and would be very tedious to write down as a group. So the first reason we reach for linear algebra is for a more compact representation of our mathematical formulae.

# %% [markdown]
# ### Running Example: Olympic Marathons
#
# Now we will load in the Olympic marathon data. This is data of the olympic marath times for the men's marathon from the first olympics in 1896 up until the London 2012 olympics.

# %%
data = pods.datasets.olympic_marathon_men()
x = data['X']
y = data['Y']

# %% [markdown]
# You can see what these values are by typing:

# %%
print(x)
print(y)
# Out:
# [[1896.]
#  [1900.]
#  [1904.]
#  [1908.]
#  [1912.]
#  [1920.]
#  [1924.]
#  [1928.]
#  [1932.]
#  [1936.]
#  [1948.]
#  [1952.]
#  [1956.]
#  [1960.]
#  [1964.]
#  [1968.]
#  [1972.]
#  [1976.]
#  [1980.]
#  [1984.]
#  [1988.]
#  [1992.]
#  [1996.]
#  [2000.]
#  [2004.]
#  [2008.]
#  [2012.]]
# [[4.47083333]
#  [4.46472926]
#  [5.22208333]
#  [4.15467867]
#  [3.90331675]
#  [3.56951267]
#  [3.82454477]
#  [3.62483707]
#  [3.59284275]
#  [3.53880792]
#  [3.67010309]
#  [3.39029111]
#  [3.43642612]
#  [3.20583007]
#  [3.13275665]
#  [3.32819844]
#  [3.13583758]
#  [3.0789588 ]
#  [3.10581822]
#  [3.06552909]
#  [3.09357349]
#  [3.16111704]
#  [3.14255244]
#  [3.08527867]
#  [3.10265829]
#  [2.99877553]
#  [3.03392977]]

# %% [markdown]
# Note that they are not `pandas` data frames for this example, they are just arrays of dimensionality $n\times 1$, where $n$ is the number of data.

# %% [markdown]
# The aim of this lab is to have you coding linear regression in python. We will do it in two ways, once using iterative updates (coordinate ascent) and then using linear algebra. The linear algebra approach will not only work much better, it is easy to extend to multiple input linear regression and *non-linear* regression using basis functions.

# %% [markdown]
# ### Plotting the Data
#
# You can make a plot of $y$ vs $x$ with the following command:

# %%
# %matplotlib inline 
import pylab as plt

plt.plot(x, y, 'rx')
plt.xlabel('year')
plt.ylabel('pace in min/km')
# Out:
# Text(0,0.5,'pace in min/km')

# %% [markdown]
# ### Maximum Likelihood: Iterative Solution

# %% [markdown]
# Now we will take the maximum likelihood approach we derived in the lecture to fit a line, $y_i=mx_i + c$, to the data you've plotted. We are trying to minimize the error function:

# %% [markdown]
# $$E(m, c) =  \sum_{i=1}^n(y_i-mx_i-c)^2$$

# %% [markdown]
# with respect to $m$, $c$ and $\sigma^2$. We can start with an initial guess for $m$,

# %%
m = -0.4
c = 80

# %% [markdown]
# Then we use the maximum likelihood update to find an estimate for the offset, $c$.
#
# ### Coordinate Descent
#
# In the movie recommender system example, we minimised the objective function by steepest descent based gradient methods. Our updates required us to compute the gradient at the position we were located, then to update the gradient according to the direction of steepest descent. This time, we will take another approach. It is known as *coordinate descent*. In coordinate descent, we choose to move one parameter at a time. Ideally, we design an algorithm that at each step moves the parameter to its minimum value. At each step we choose to move the individual parameter to its minimum.
#
# To find the minimum, we look for the point in the curve where the gradient is zero. This can be found by taking the gradient of $E(m,c)$ with respect to the parameter.
#
# #### Update for Offset
#
# Let's consider the parameter $c$ first. The gradient goes nicely through the summation operator, and we obtain
# $$
# \frac{\text{d}E(m,c)}{\text{d}c} = -\sum_{i=1}^n 2(y_i-mx_i-c).
# $$
# Now we want the point that is a minimum. A minimum is an example of a [*stationary point*](http://en.wikipedia.org/wiki/Stationary_point), the stationary points are those points of the function where the gradient is zero. They are found by solving the equation for $\frac{\text{d}E(m,c)}{\text{d}c} = 0$. Substituting in to our gradient, we can obtain the following equation,
# $$
# 0 = -\sum_{i=1}^n 2(y_i-mx_i-c)
# $$
# which can be reorganised as follows,
# $$
# c^* = \frac{\sum_{i=1}^n(y_i-m^*x_i)}{n}.
# $$
# The fact that the stationary point is easily extracted in this manner implies that the solution is *unique*. There is only one stationary point for this system. Traditionally when trying to determine the type of stationary point we have encountered we now compute the *second derivative*,
# $$
# \frac{\text{d}^2E(m,c)}{\text{d}c^2} = 2n.
# $$
# The second derivative is positive, which in turn implies that we have found a minimum of the function. This means that setting $c$ in this way will take us to the lowest point along that axes.

# %%
# set c to the minimum
#print(m)
c = (y - m*x).mean()
print(c)
# Out:
# 786.0197711453593

# %% [markdown]
# #### Update for Slope
#
# Now we have the offset set to the minimum value, in coordinate descent, the next step is to optimise another parameter. Only one further parameter remains. That is the slope of the system.
#
# Now we can turn our attention to the slope. We once again peform the same set of computations to find the minima. We end up with an update equation of the following form.
#
# $$m^* = \frac{\sum_{i=1}^n (y_i - c)x_i}{\sum_{i=1}^n x_i^2}$$
#
# Communication of mathematics in data science is an essential skill, in a moment, you will be asked to rederive the equation above. Before we do that, however, we will briefly review how to write mathematics in the notebook.
#
# ### $\LaTeX$ for Maths
#
# These cells use [Markdown format](http://en.wikipedia.org/wiki/Markdown). You can include maths in your markdown using [$\LaTeX$ syntax](http://en.wikipedia.org/wiki/LaTeX), all you have to do is write your answer inside dollar signs, as follows:
#
# To write a fraction, we write `$\frac{a}{b}$`, and it will display like this $\frac{a}{b}$. To write a subscript we write `$a_b$` which will appear as $a_b$. To write a superscript (for example in a polynomial) we write `$a^b$` which will appear as $a^b$. There are lots of other macros as well, for example we can do greek letters such as `$\alpha, \beta, \gamma$` rendering as $\alpha, \beta, \gamma$. And we can do sum and intergral signs as `$\sum \int \int$`.
#
# You can combine many of these operations together for composing expressions.

# %% [markdown]
# ### Assignment Question 1
#
# Convert the following python code expressions into $\LaTeX$j, writing your answers below. In each case write your answer as a single equality (i.e. your maths should only contain one expression, not several lines of expressions). For the purposes of your $\LaTeX$ please assume that `x` and `w` are $n$ dimensional vectors.
#
# (a)
# ``` python
# f = x.sum()
# ```
#
# (b)
# ``` python
# m = x.mean()
# ```
#
# (c)
# ``` python
# g = (x*w).sum()
# ```
#
# *15 marks*

# %% [markdown]
# #### Question 1 Answer
#
# Write your answer to the question in this box.
#
# (a)
# $$
# f(x) = \sum_{i=1}^n x_i
# $$
#
# (b)
# $$
# m(x) = \frac{\sum_{i=1}^n x_i}{n}
# $$
#
# (c)
# $$
# g(x) = \sum_{i=1}^n (x_i . w_i)
# $$

# %% [markdown]
# ### Gradient With Respect to the Slope
# Now that you've had a little training in writing maths with $\LaTeX$, we will be able to use it to answer questions. The next thing we are going to do is a little differentiation practice.

# %% [markdown]
# ### Assignment Question 2
#
# Derive the the gradient of the objective function with respect to the slope, $m$. Rearrange it to show that the update equation written above does find the stationary points of the objective function. By computing its derivative show that it's a minimum.
#
# *20 marks*

# %% [markdown]
# #### Question 2 Answer
#
# Write your answer to the question in this box.
#
# Taking derivative of the equation wrt $m$ :
# $$E(m, c) =  \sum_{i=1}^n(y_i-mx_i-c)^2$$
#
#
# $$
# \frac{\text{d}E(m,c)}{\text{d}m} = -\sum_{i=1}^n 2(y_i-mx_i-c)x_i.
# $$
#
# As we want a point that is the minimum,solving the following equation $\frac{\text{d}E(m,c)}{\text{d}m} = 0$
#
# $$
# 0 = -\sum_{i=1}^n 2(y_i-mx_i-c)x_i.
# $$
#
# $$
# 0 = -\sum_{i=1}^n 2(y_i.x_i)+\sum_{i=1}^n 2m(x_i)^2+\sum_{i=1}^n 2cx_i
# $$
#
# $$
# \sum_{i=1}^n m(x_i)^2 = \sum_{i=1}^n (y_i-c)x_i
# $$
#
# $$
# m = \frac{\sum_{i=1}^n (y_i-c)x_i}{\sum_{i=1}^n (x_i)^2}
# $$
#
#
# Now taking the second deravative:
#
# $$
# \frac{\text{d}^2E(m,c)}{\text{d}m^2} = 2x_i^2.
# $$
#
# As the second derivative is positive, it implies that we have found the minimum.

# %%
m = ((y - c)*x).sum()/(x**2).sum()
print(m)
# Out:
# -0.3998724072997095

# %% [markdown]
# We can have a look at how good our fit is by computing the prediction across the input space. First create a vector of 'test points',

# %%
import numpy as np
x_test = np.linspace(1890, 2020, 130)[:, None]   ## np.linspace > Return evenly spaced numbers over a specified interval.
print(x_test)
# Out:
# [[1890.        ]
#  [1891.00775194]
#  [1892.01550388]
#  [1893.02325581]
#  [1894.03100775]
#  [1895.03875969]
#  [1896.04651163]
#  [1897.05426357]
#  [1898.0620155 ]
#  [1899.06976744]
#  [1900.07751938]
#  [1901.08527132]
#  [1902.09302326]
#  [1903.10077519]
#  [1904.10852713]
#  [1905.11627907]
#  [1906.12403101]
#  [1907.13178295]
#  [1908.13953488]
#  [1909.14728682]
#  [1910.15503876]
#  [1911.1627907 ]
#  [1912.17054264]
#  [1913.17829457]
#  [1914.18604651]
#  [1915.19379845]
#  [1916.20155039]
#  [1917.20930233]
#  [1918.21705426]
#  [1919.2248062 ]
#  [1920.23255814]
#  [1921.24031008]
#  [1922.24806202]
#  [1923.25581395]
#  [1924.26356589]
#  [1925.27131783]
#  [1926.27906977]
#  [1927.28682171]
#  [1928.29457364]
#  [1929.30232558]
#  [1930.31007752]
#  [1931.31782946]
#  [1932.3255814 ]
#  [1933.33333333]
#  [1934.34108527]
#  [1935.34883721]
#  [1936.35658915]
#  [1937.36434109]
#  [1938.37209302]
#  [1939.37984496]
#  [1940.3875969 ]
#  [1941.39534884]
#  [1942.40310078]
#  [1943.41085271]
#  [1944.41860465]
#  [1945.42635659]
#  [1946.43410853]
#  [1947.44186047]
#  [1948.4496124 ]
#  [1949.45736434]
#  [1950.46511628]
#  [1951.47286822]
#  [1952.48062016]
#  [1953.48837209]
#  [1954.49612403]
#  [1955.50387597]
#  [1956.51162791]
#  [1957.51937984]
#  [1958.52713178]
#  [1959.53488372]
#  [1960.54263566]
#  [1961.5503876 ]
#  [1962.55813953]
#  [1963.56589147]
#  [1964.57364341]
#  [1965.58139535]
#  [1966.58914729]
#  [1967.59689922]
#  [1968.60465116]
#  [1969.6124031 ]
#  [1970.62015504]
#  [1971.62790698]
#  [1972.63565891]
#  [1973.64341085]
#  [1974.65116279]
#  [1975.65891473]
#  [1976.66666667]
#  [1977.6744186 ]
#  [1978.68217054]
#  [1979.68992248]
#  [1980.69767442]
#  [1981.70542636]
#  [1982.71317829]
#  [1983.72093023]
#  [1984.72868217]
#  [1985.73643411]
#  [1986.74418605]
#  [1987.75193798]
#  [1988.75968992]
#  [1989.76744186]
#  [1990.7751938 ]
#  [1991.78294574]
#  [1992.79069767]
#  [1993.79844961]
#  [1994.80620155]
#  [1995.81395349]
#  [1996.82170543]
#  [1997.82945736]
#  [1998.8372093 ]
#  [1999.84496124]
#  [2000.85271318]
#  [2001.86046512]
#  [2002.86821705]
#  [2003.87596899]
#  [2004.88372093]
#  [2005.89147287]
#  [2006.89922481]
#  [2007.90697674]
#  [2008.91472868]
#  [2009.92248062]
#  [2010.93023256]
#  [2011.9379845 ]
#  [2012.94573643]
#  [2013.95348837]
#  [2014.96124031]
#  [2015.96899225]
#  [2016.97674419]
#  [2017.98449612]
#  [2018.99224806]
#  [2020.        ]]

# %% [markdown]
# Now use this vector to compute some test predictions,

# %%
f_test = m*x_test + c
print(m)
print(c)
print(f_test)
# Out:
# -0.3998724072997095
# 786.0197711453593
# [[ 30.26092135]
#  [ 29.85794916]
#  [ 29.45497696]
#  [ 29.05200477]
#  [ 28.64903258]
#  [ 28.24606038]
#  [ 27.84308819]
#  [ 27.440116  ]
#  [ 27.0371438 ]
#  [ 26.63417161]
#  [ 26.23119941]
#  [ 25.82822722]
#  [ 25.42525503]
#  [ 25.02228283]
#  [ 24.61931064]
#  [ 24.21633845]
#  [ 23.81336625]
#  [ 23.41039406]
#  [ 23.00742187]
#  [ 22.60444967]
#  [ 22.20147748]
#  [ 21.79850529]
#  [ 21.39553309]
#  [ 20.9925609 ]
#  [ 20.58958871]
#  [ 20.18661651]
#  [ 19.78364432]
#  [ 19.38067213]
#  [ 18.97769993]
#  [ 18.57472774]
#  [ 18.17175555]
#  [ 17.76878335]
#  [ 17.36581116]
#  [ 16.96283897]
#  [ 16.55986677]
#  [ 16.15689458]
#  [ 15.75392239]
#  [ 15.35095019]
#  [ 14.947978  ]
#  [ 14.54500581]
#  [ 14.14203361]
#  [ 13.73906142]
#  [ 13.33608923]
#  [ 12.93311703]
#  [ 12.53014484]
#  [ 12.12717265]
#  [ 11.72420045]
#  [ 11.32122826]
#  [ 10.91825607]
#  [ 10.51528387]
#  [ 10.11231168]
#  [  9.70933949]
#  [  9.30636729]
#  [  8.9033951 ]
#  [  8.50042291]
#  [  8.09745071]
#  [  7.69447852]
#  [  7.29150632]
#  [  6.88853413]
#  [  6.48556194]
#  [  6.08258974]
#  [  5.67961755]
#  [  5.27664536]
#  [  4.87367316]
#  [  4.47070097]
#  [  4.06772878]
#  [  3.66475658]
#  [  3.26178439]
#  [  2.8588122 ]
#  [  2.45584   ]
#  [  2.05286781]
#  [  1.64989562]
#  [  1.24692342]
#  [  0.84395123]
#  [  0.44097904]
#  [  0.03800684]
#  [ -0.36496535]
#  [ -0.76793754]
#  [ -1.17090974]
#  [ -1.57388193]
#  [ -1.97685412]
#  [ -2.37982632]
#  [ -2.78279851]
#  [ -3.1857707 ]
#  [ -3.5887429 ]
#  [ -3.99171509]
#  [ -4.39468728]
#  [ -4.79765948]
#  [ -5.20063167]
#  [ -5.60360386]
#  [ -6.00657606]
#  [ -6.40954825]
#  [ -6.81252044]
#  [ -7.21549264]
#  [ -7.61846483]
#  [ -8.02143702]
#  [ -8.42440922]
#  [ -8.82738141]
#  [ -9.2303536 ]
#  [ -9.6333258 ]
#  [-10.03629799]
#  [-10.43927018]
#  [-10.84224238]
#  [-11.24521457]
#  [-11.64818676]
#  [-12.05115896]
#  [-12.45413115]
#  [-12.85710335]
#  [-13.26007554]
#  [-13.66304773]
#  [-14.06601993]
#  [-14.46899212]
#  [-14.87196431]
#  [-15.27493651]
#  [-15.6779087 ]
#  [-16.08088089]
#  [-16.48385309]
#  [-16.88682528]
#  [-17.28979747]
#  [-17.69276967]
#  [-18.09574186]
#  [-18.49871405]
#  [-18.90168625]
#  [-19.30465844]
#  [-19.70763063]
#  [-20.11060283]
#  [-20.51357502]
#  [-20.91654721]
#  [-21.31951941]
#  [-21.7224916 ]]

# %% [markdown]
# Now plot those test predictions with a blue line on the same plot as the data,

# %%
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')

# %% [markdown]
# The fit isn't very good, we need to iterate between these parameter updates in a loop to improve the fit, we have to do this several times,

# %%
for i in np.arange(10):
    m = ((y - c)*x).sum()/(x*x).sum()
    c = (y-m*x).sum()/y.shape[0]
print(m)
print(c)
# Out:
# -0.3987259642505432
# 783.5273797273478

# %% [markdown]
# And let's try plotting the result again

# %%
f_test = m*x_test + c
print(f_test)
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')
# Out:
# [[ 29.93530729]
#  [ 29.53349043]
#  [ 29.13167357]
#  [ 28.7298567 ]
#  [ 28.32803984]
#  [ 27.92622298]
#  [ 27.52440611]
#  [ 27.12258925]
#  [ 26.72077239]
#  [ 26.31895553]
#  [ 25.91713866]
#  [ 25.5153218 ]
#  [ 25.11350494]
#  [ 24.71168807]
#  [ 24.30987121]
#  [ 23.90805435]
#  [ 23.50623748]
#  [ 23.10442062]
#  [ 22.70260376]
#  [ 22.30078689]
#  [ 21.89897003]
#  [ 21.49715317]
#  [ 21.0953363 ]
#  [ 20.69351944]
#  [ 20.29170258]
#  [ 19.88988571]
#  [ 19.48806885]
#  [ 19.08625199]
#  [ 18.68443512]
#  [ 18.28261826]
#  [ 17.8808014 ]
#  [ 17.47898453]
#  [ 17.07716767]
#  [ 16.67535081]
#  [ 16.27353395]
#  [ 15.87171708]
#  [ 15.46990022]
#  [ 15.06808336]
#  [ 14.66626649]
#  [ 14.26444963]
#  [ 13.86263277]
#  [ 13.4608159 ]
#  [ 13.05899904]
#  [ 12.65718218]
#  [ 12.25536531]
#  [ 11.85354845]
#  [ 11.45173159]
#  [ 11.04991472]
#  [ 10.64809786]
#  [ 10.246281  ]
#  [  9.84446413]
#  [  9.44264727]
#  [  9.04083041]
#  [  8.63901354]
#  [  8.23719668]
#  [  7.83537982]
#  [  7.43356295]
#  [  7.03174609]
#  [  6.62992923]
#  [  6.22811237]
#  [  5.8262955 ]
#  [  5.42447864]
#  [  5.02266178]
#  [  4.62084491]
#  [  4.21902805]
#  [  3.81721119]
#  [  3.41539432]
#  [  3.01357746]
#  [  2.6117606 ]
#  [  2.20994373]
#  [  1.80812687]
#  [  1.40631001]
#  [  1.00449314]
#  [  0.60267628]
#  [  0.20085942]
#  [ -0.20095745]
#  [ -0.60277431]
#  [ -1.00459117]
#  [ -1.40640804]
#  [ -1.8082249 ]
#  [ -2.21004176]
#  [ -2.61185863]
#  [ -3.01367549]
#  [ -3.41549235]
#  [ -3.81730921]
#  [ -4.21912608]
#  [ -4.62094294]
#  [ -5.0227598 ]
#  [ -5.42457667]
#  [ -5.82639353]
#  [ -6.22821039]
#  [ -6.63002726]
#  [ -7.03184412]
#  [ -7.43366098]
#  [ -7.83547785]
#  [ -8.23729471]
#  [ -8.63911157]
#  [ -9.04092844]
#  [ -9.4427453 ]
#  [ -9.84456216]
#  [-10.24637903]
#  [-10.64819589]
#  [-11.05001275]
#  [-11.45182962]
#  [-11.85364648]
#  [-12.25546334]
#  [-12.65728021]
#  [-13.05909707]
#  [-13.46091393]
#  [-13.86273079]
#  [-14.26454766]
#  [-14.66636452]
#  [-15.06818138]
#  [-15.46999825]
#  [-15.87181511]
#  [-16.27363197]
#  [-16.67544884]
#  [-17.0772657 ]
#  [-17.47908256]
#  [-17.88089943]
#  [-18.28271629]
#  [-18.68453315]
#  [-19.08635002]
#  [-19.48816688]
#  [-19.88998374]
#  [-20.29180061]
#  [-20.69361747]
#  [-21.09543433]
#  [-21.4972512 ]
#  [-21.89906806]]

# %% [markdown]
# Clearly we need more iterations than 10! In the next question you will add more iterations and report on the error as optimisation proceeds.

# %% [markdown]
# ### Assignment Question 3
#
# There is a problem here, we seem to need many interations to get to a good solution. Let's explore what's going on. Write code which alternates between updates of `c` and `m`. Include the following features in your code.
#
# (a) Initialise with `m=-0.4` and `c=80`.
# (b) Every 10 iterations compute the value of the objective function for the training data and print it to the screen (you'll find hints on this in the lab from last week.
# (c) Cause the code to stop running when the error change over less than 10 iterations is smaller than $1\times10^{-4}$. This is known as a stopping criterion.
#
# Why do we need so many iterations to get to the solution?
#
# *25 marks*

# %%
# Question 3 Answer Code
# Write code for you answer to this question in this box
# Do not delete these comments, otherwise you will get zero for this answer.
# Make sure your code has run and the answer is correct *before* submitting your notebook for marking.

# initialising the variables

m= -0.4
c = 80
error_old = 0.
x_test = np.linspace(1890, 2020, 27)[:, None]
n_points = x_test.shape[0]
outerLoop_itr=5000
iterations = 0
error_diff = 0
obj_counter = 0

#implementing the algorithm

for i in np.arange(outerLoop_itr):
    obj=0.
    for j in np.arange(10): 
        m = ((y - c)*x).sum()/(x*x).sum()  
        c = (y-m*x).sum()/y.shape[0]
    f_test = m*x_test + c
    error_new = (y - f_test).sum()
    obj += error_new*error_new
    error_diff = abs(error_new-error_old)
    error_old = error_new
    print("error difference=", error_diff)
    if(error_diff < 0.0001):  # stopping criterion
        print("error_diff after error is less than 0.0001:",error_diff)
        break
    obj_counter += 1
    if(obj_counter == 10):
        print("obj function after every 10 iterations:",obj)
        obj_counter = 0
    
    iterations +=1  # to keep the count of iterations required to reach the stopping criterion
           
print("value of m:",m)
print("value of c:",c)
print("Number of iterations required:",iterations)
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')
# Out:
# error difference= 1.3656254530723908
# error difference= 0.002999933507027208
# error difference= 0.0029900579741450883
# error difference= 0.002980214949715787
# error difference= 0.0029704043286926662
# error difference= 0.0029606260026184827
# error difference= 0.0029508798663613334
# error difference= 0.0029411658131692775
# error difference= 0.00293148373887675
# error difference= 0.0029218335356659964
# obj function after every 10 iterations: 1.7928643697348652
# error difference= 0.002912215100877802
# error difference= 0.0029026283303466016
# error difference= 0.0028930731166667556
# error difference= 0.0028835493588559302
# error difference= 0.0028740569530185667
# error difference= 0.0028645957947475154
# error difference= 0.002855165781753044
# error difference= 0.0028457668120296375
# error difference= 0.002836398782193328
# error difference= 0.002827061591801794
# obj function after every 10 iterations: 1.716845056192849
# error difference= 0.00281775513850846
# error difference= 0.002808479321259938
# error difference= 0.0027992340393865334
# error difference= 0.0027900191918917017
# error difference= 0.0027808346793278815
# error difference= 0.0027716804006985285
# error difference= 0.0027625562579061125
# error difference= 0.0027534621511904334
# error difference= 0.0027443979804644414
# error difference= 0.0027353636498048672
# obj function after every 10 iterations: 1.6448589840611605
# error difference= 0.0027263590582293773
# error difference= 0.0027173841093031115
# error difference= 0.0027084387047580094
# error difference= 0.0026995227485144824
# error difference= 0.0026906361429297476
# error difference= 0.002681778790289968
# error difference= 0.002672950596277701
# error difference= 0.002664151463321218
# error difference= 0.002655381297344661
# error difference= 0.002646640001103151
# obj function after every 10 iterations: 1.576675295252744
# error difference= 0.0026379274808192577
# error difference= 0.0026292436411949893
# error difference= 0.0026205883881118552
# error difference= 0.0026119616274797863
# error difference= 0.0026033632656776717
# error difference= 0.0025947932088143943
# error difference= 0.002586251363965175
# error difference= 0.0025777376379778616
# error difference= 0.0025692519383397894
# error difference= 0.002560794173177783
# obj function after every 10 iterations: 1.5120770040379268
# error difference= 0.0025523642502918165
# error difference= 0.0025439620777518712
# error difference= 0.0025355875650632242
# error difference= 0.0025272406197842656
# error difference= 0.002518921152955045
# error difference= 0.0025106290718923674
# error difference= 0.002502364288503145
# error difference= 0.002494126711852118
# error difference= 0.002485916253050391
# error difference= 0.0024777328210632277
# obj function after every 10 iterations: 1.4508601396369671
# error difference= 0.0024695763298154816
# error difference= 0.002461446688684532
# error difference= 0.002453343809278863
# error difference= 0.0024452676038038135
# error difference= 0.002437217985090001
# error difference= 0.0024291948646606443
# error difference= 0.002421198155758475
# error difference= 0.00241322777112174
# error difference= 0.0024052836249239817
# error difference= 0.0023973656294700163
# obj function after every 10 iterations: 1.3928329426345964
# error difference= 0.0023894736997007726
# error difference= 0.0023816077506069178
# error difference= 0.0023737676932142904
# error difference= 0.002365953446478386
# error difference= 0.0023581649237200963
# error difference= 0.0023504020386866387
# error difference= 0.0023426647096513875
# error difference= 0.002334952850638672
# error difference= 0.002327266378884474
# error difference= 0.0023196052104097475
# obj function after every 10 iterations: 1.337815111797431
# error difference= 0.002311969261349134
# error difference= 0.002304358448760979
# error difference= 0.002296772691934734
# error difference= 0.0022892119057047466
# error difference= 0.002281676009211253
# error difference= 0.0022741649198323444
# error difference= 0.0022666785568645764
# error difference= 0.0022592168384605316
# error difference= 0.002251779682808319
# error difference= 0.0022443670097871404
# obj function after every 10 iterations: 1.2856370981136787
# error difference= 0.0022369787396598895
# error difference= 0.0022296147898828167
# error difference= 0.0022222750827296522
# error difference= 0.0022149595360403396
# error difference= 0.0022076680723372988
# error difference= 0.0022004006112936736
# error difference= 0.002193157074252383
# error difference= 0.002185937382016334
# error difference= 0.0021787414570226815
# error difference= 0.002171569220010383
# obj function after every 10 iterations: 1.2361394430571193
# error difference= 0.0021644205928765814
# error difference= 0.002157295499678469
# error difference= 0.002150193860757099
# error difference= 0.002143115600418799
# error difference= 0.002136060640481219
# error difference= 0.0021290289052586786
# error difference= 0.0021220203177065855
# error difference= 0.002115034802685045
# error difference= 0.0021080722821835707
# error difference= 0.00210113268234835
# obj function after every 10 iterations: 1.1891721583130688
# error difference= 0.0020942159274639494
# error difference= 0.0020873219416301936
# error difference= 0.002080450649749821
# error difference= 0.0020736019782674475
# error difference= 0.0020667758515671153
# error difference= 0.0020599721961005457
# error difference= 0.0020531909378291857
# error difference= 0.002046432002728693
# error difference= 0.002039695317776591
# error difference= 0.002032980809168805
# obj function after every 10 iterations: 1.1445941442855352
# error difference= 0.0020262884038402262
# error difference= 0.002019618030487891
# error difference= 0.002012969614177962
# error difference= 0.0020063430844459162
# error difference= 0.001999738368766657
# error difference= 0.001993155394877988
# error difference= 0.0019865940922656478
# error difference= 0.0019800543885892807
# error difference= 0.001973536212723559
# error difference= 0.0019670394950210834
# obj function after every 10 iterations: 1.1022726450103149
# error difference= 0.0019605641632978177
# error difference= 0.0019541101477713596
# error difference= 0.0019476773781548218
# error difference= 0.0019412657853337123
# error difference= 0.001934875299006933
# error difference= 0.0019285058490652318
# error difference= 0.001922157366905708
# error difference= 0.001915829783442291
# error difference= 0.0019095230307328848
# error difference= 0.0019032370378511132
# obj function after every 10 iterations: 1.0620827371068209
# error difference= 0.0018969717391712493
# error difference= 0.0018907270643353513
# error difference= 0.0018845029473268937
# error difference= 0.0018782993192445474
# error difference= 0.0018721161128638641
# error difference= 0.0018659532611593477
# error difference= 0.001859810696991815
# error difference= 0.0018536883544797433
# error difference= 0.0018475861647502256
# error difference= 0.001841504063662569
# obj function after every 10 iterations: 1.0239068506629434
# error difference= 0.0018354419847383951
# error difference= 0.0018293998610161566
# error difference= 0.0018233776280496272
# error difference= 0.001817375219332007
# error difference= 0.0018113925698344246
# error difference= 0.0018054296156648775
# error difference= 0.0017994862899257669
# error difference= 0.0017935625295990576
# error difference= 0.0017876582702882615
# error difference= 0.0017817734465666035
# obj function after every 10 iterations: 0.9876343200206696
# error difference= 0.0017759079956221058
# error difference= 0.001770061853456184
# error difference= 0.0017642349554662928
# error difference= 0.0017584272397783707
# error difference= 0.0017526386425998908
# error difference= 0.0017468691013391435
# error difference= 0.001741118551869647
# error difference= 0.0017353869339089556
# error difference= 0.0017296741827976803
# error difference= 0.00172398023866549
# obj function after every 10 iterations: 0.9531609625805916
# error difference= 0.0017183050377838072
# error difference= 0.0017126485196143904
# error difference= 0.0017070106226313442
# error difference= 0.0017013912837740008
# error difference= 0.0016957904449199646
# error difference= 0.0016902080420422294
# error difference= 0.0016846440172955113
# error difference= 0.0016790983082017874
# error difference= 0.001673570854741513
# error difference= 0.0016680615982309632
# obj function after every 10 iterations: 0.9203886838539009
# error difference= 0.0016625704772081917
# error difference= 0.0016570974323499854
# error difference= 0.0016516424043260258
# error difference= 0.0016462053342181093
# error difference= 0.0016407861615803654
# error difference= 0.0016353848296191131
# error difference= 0.0016300012776255812
# error difference= 0.0016246354476550096
# error difference= 0.0016192872826152893
# error difference= 0.0016139567219823903
# obj function after every 10 iterations: 0.8892251071104292
# error difference= 0.0016086437100781836
# error difference= 0.001603348187870779
# error difference= 0.0015980700976996332
# error difference= 0.0015928093830339662
# error difference= 0.0015875659861208646
# error difference= 0.0015823398502377017
# error difference= 0.0015771309176670911
# error difference= 0.0015719391331998622
# error difference= 0.0015667644392465263
# error difference= 0.0015616067801076383
# obj function after every 10 iterations: 0.8595832260745954
# error difference= 0.001556466099366105
# error difference= 0.0015513423421253947
# error difference= 0.0015462354503128495
# error difference= 0.0015411453713696233
# error difference= 0.0015360720483030832
# error difference= 0.001531015425292992
# error difference= 0.0015259754494394429
# error difference= 0.001520952064481662
# error difference= 0.0015159452156012776
# error difference= 0.0015109548492944214
# obj function after every 10 iterations: 0.831381079214295
# error difference= 0.0015059809104513988
# error difference= 0.001501023345468866
# error difference= 0.0014960821009495362
# error difference= 0.0014911571220537212
# error difference= 0.0014862483559170414
# error difference= 0.0014813557490143126
# error difference= 0.0014764792482395706
# error difference= 0.0014716188006715925
# error difference= 0.0014667743528917754
# error difference= 0.0014619458530802376
# obj function after every 10 iterations: 0.8045414442632234
# error difference= 0.001457133247946274
# error difference= 0.0014523364854852616
# error difference= 0.0014475555137920537
# error difference= 0.0014427902805280723
# error difference= 0.0014380407342069468
# error difference= 0.0014333068222924794
# error difference= 0.0014285884952656147
# error difference= 0.0014238856996655613
# error difference= 0.001419198385526954
# error difference= 0.0014145265015486075
# obj function after every 10 iterations: 0.7789915517036566
# error difference= 0.001409869997694102
# error difference= 0.0014052288211914288
# error difference= 0.0014006029244626461
# error difference= 0.0013959922551691761
# error difference= 0.0013913967634593405
# error difference= 0.0013868164010233386
# error difference= 0.0013822511157357553
# error difference= 0.0013777008589244133
# error difference= 0.0013731655819597677
# error difference= 0.0013686452334553678
# obj function after every 10 iterations: 0.7546628160200709
# error difference= 0.001364139766963035
# error difference= 0.0013596491312597436
# error difference= 0.0013551732790588744
# error difference= 0.0013507121600611072
# error difference= 0.0013462657273777268
# error difference= 0.001341833931540748
# error difference= 0.0013374167248443314
# error difference= 0.0013330140598952767
# error difference= 0.0013286258875808699
# error difference= 0.0013242521607850222
# obj function after every 10 iterations: 0.731490583602101
# error difference= 0.001319892832029268
# error difference= 0.00131554785380672
# error difference= 0.0013112171788094429
# error difference= 0.0013069007601629323
# error difference= 0.0013025985511490035
# error difference= 0.001298310503713651
# error difference= 0.0012940365732916348
# error difference= 0.0012897767113955183
# error difference= 0.0012855308731332116
# error difference= 0.0012812990116373157
# obj function after every 10 iterations: 0.7094138962535257
# error difference= 0.0012770810807793964
# error difference= 0.0012728770356815744
# error difference= 0.0012686868294693454
# error difference= 0.0012645104171511434
# error difference= 0.0012603477534085528
# error difference= 0.0012561987924897267
# error difference= 0.0012520634903196992
# error difference= 0.0012479418000026499
# error difference= 0.0012438336787710114
# error difference= 0.001239739081107416
# obj function after every 10 iterations: 0.688375269322693
# error difference= 0.001235657962688208
# error difference= 0.0012315902784223454
# error difference= 0.0012275359848459289
# error difference= 0.0012234950378129383
# error difference= 0.0012194673934473599
# error difference= 0.001215453006949474
# error difference= 0.0012114518365393678
# error difference= 0.001207463837054945
# error difference= 0.0012034889656504788
# error difference= 0.0011995271795655071
# obj function after every 10 iterations: 0.6683204835405967
# error difference= 0.0011955784348245402
# error difference= 0.0011916426895410837
# error difference= 0.0011877199002015004
# error difference= 0.0011838100242371752
# error difference= 0.0011799130194773966
# error difference= 0.0011760288436022392
# error difference= 0.0011721574533822832
# error difference= 0.001168298807712631
# error difference= 0.001164452864578891
# error difference= 0.0011606195820093035
# obj function after every 10 iterations: 0.649198389708971
# error difference= 0.0011567989181813232
# error difference= 0.001152990831577938
# error difference= 0.0011491952812221484
# error difference= 0.001145412224694553
# error difference= 0.0011416416230005666
# error difference= 0.0011378834326549736
# error difference= 0.0011341376139881731
# error difference= 0.0011304041272381937
# error difference= 0.0011266829295450975
# error difference= 0.001122973983207487
# obj function after every 10 iterations: 0.6309607254219662
# error difference= 0.0011192772452801591
# error difference= 0.0011155926765269442
# error difference= 0.0011119202380669435
# error difference= 0.0011082598883689343
# error difference= 0.0011046115878485807
# error difference= 0.0011009752985486898
# error difference= 0.0010973509780995983
# error difference= 0.00109373858982309
# error difference= 0.001090138092116888
# error difference= 0.001086549448004348
# obj function after every 10 iterations: 0.6135619430808296
# error difference= 0.0010829726168424259
# error difference= 0.001079407560133916
# error difference= 0.001075854240099261
# error difference= 0.0010723126160243623
# error difference= 0.0010687826521049715
# error difference= 0.0010652643081456858
# error difference= 0.001061757545365083
# error difference= 0.0010582623273762692
# error difference= 0.00105477861502834
# error difference= 0.0010513063712949133
# obj function after every 10 iterations: 0.5969590484813344
# error difference= 0.001047845557117455
# error difference= 0.0010443961362369691
# error difference= 0.0010409580705186272
# error difference= 0.00103753132223261
# error difference= 0.001034115854878337
# error difference= 0.001030711631308634
# error difference= 0.0010273186133673562
# error difference= 0.0010239367654065745
# error difference= 0.0010205660498812108
# error difference= 0.001017206430894646
# obj function after every 10 iterations: 0.5811114493251243
# error difference= 0.0010138578714702362
# error difference= 0.0010105203348018676
# error difference= 0.0010071937854903013
# error difference= 0.0010038781867294233
# error difference= 0.001000573502544455
# error difference= 0.0009972796970529885
# error difference= 0.0009939967347705192
# error difference= 0.000990724579629898
# error difference= 0.0009874631962532021
# error difference= 0.0009842125486656528
# obj function after every 10 iterations: 0.5659808130189192
# error difference= 0.0009809726026048793
# error difference= 0.0009777433215845122
# error difference= 0.000974524671065069
# error difference= 0.0009713166168552334
# error difference= 0.000968119122354949
# error difference= 0.0009649321542752887
# error difference= 0.0009617556775083358
# error difference= 0.0009585896572019692
# error difference= 0.0009554340583548537
# error difference= 0.0009522888489854608
# obj function after every 10 iterations: 0.5515309331960999
# error difference= 0.0009491539929769033
# error difference= 0.0009460294557470661
# error difference= 0.0009429152055204781
# error difference= 0.0009398112065497344
# error difference= 0.0009367174252545851
# error difference= 0.0009336338293053359
# error difference= 0.0009305603830824793
# error difference= 0.0009274970557271445
# error difference= 0.0009244438119253573
# error difference= 0.0009214006192621582
# obj function after every 10 iterations: 0.5377276044051603
# error difference= 0.0009183674444130929
# error difference= 0.0009153442547713553
# error difference= 0.0009123310170195964
# error difference= 0.0009093276984515342
# error difference= 0.0009063342669932695
# error difference= 0.0009033506893558751
# error difference= 0.0009003769334441358
# error difference= 0.0008974129667009834
# error difference= 0.0008944587576280583
# error difference= 0.0008915142727872194
# obj function after every 10 iterations: 0.5245385044608077
# error difference= 0.0008885794820869819
# error difference= 0.0008856543516699844
# error difference= 0.0008827388507057776
# error difference= 0.000879832946964143
# error difference= 0.0008769366094654174
# error difference= 0.0008740498070380909
# error difference= 0.0008711725072174659
# error difference= 0.000868304678839138
# error difference= 0.0008654462917832006
# error difference= 0.000862597314196023
# obj function after every 10 iterations: 0.511933083972268
# error difference= 0.0008597577148634628
# error difference= 0.0008569274634808721
# error difference= 0.0008541065289620065
# error difference= 0.000851294880618525
# error difference= 0.0008484924887142142
# error difference= 0.0008456993207062169
# error difference= 0.0008429153492457431
# error difference= 0.0008401405412286067
# error difference= 0.0008373748679133541
# error difference= 0.0008346182990024431
# obj function after every 10 iterations: 0.4998824626175237
# error difference= 0.0008318708044541268
# error difference= 0.000829132354390083
# error difference= 0.0008264029191806799
# error difference= 0.0008236824691394418
# error difference= 0.0008209709741393567
# error difference= 0.0008182684056734502
# error difference= 0.0008155747338207675
# error difference= 0.0008128899290014147
# error difference= 0.0008102139623389348
# error difference= 0.0008075468048929224
# obj function after every 10 iterations: 0.48835933171767326
# error difference= 0.0008048884278579749
# error difference= 0.0008022388014268245
# error difference= 0.0007995978973340812
# error difference= 0.0007969656871935626
# error difference= 0.0007943421420293362
# error difference= 0.0007917272335120629
# error difference= 0.0007891209325450177
# error difference= 0.0007865232115946696
# error difference= 0.0007839340422890473
# error difference= 0.0007813533958156427
# obj function after every 10 iterations: 0.47733786274432843
# error difference= 0.0007787812454225218
# error difference= 0.0007762175615440015
# error difference= 0.0007736623175276236
# error difference= 0.0007711154849801005
# error difference= 0.0007685770368937028
# error difference= 0.0007660469440438078
# error difference= 0.0007635251811564103
# error difference= 0.0007610117192484722
# error difference= 0.0007585065315538486
# error difference= 0.0007560095906811171
# obj function after every 10 iterations: 0.46679362137880787
# error difference= 0.0007535208694804396
# error difference= 0.0007510403409227706
# error difference= 0.000748567978355652
# error difference= 0.0007461037542597637
# error difference= 0.0007436476423237082
# error difference= 0.0007411996159589762
# error difference= 0.0007387596475822988
# error difference= 0.0007363277120120415
# error difference= 0.0007339037820557337
# error difference= 0.0007314878314090834
# obj function after every 10 iterations: 0.4567034867758591
# error difference= 0.0007290798339028015
# error difference= 0.0007266797630620658
# error difference= 0.0007242875932860215
# error difference= 0.0007219032986327534
# error difference= 0.0007195268525137521
# error difference= 0.0007171582290865786
# error difference= 0.0007147974040790928
# error difference= 0.0007124443496309141
# error difference= 0.0007100990416191166
# error difference= 0.0007077614544073185
# obj function after every 10 iterations: 0.4470455757158669
# error difference= 0.0007054315624017704
# error difference= 0.0007031093393692345
# error difference= 0.0007007947618404842
# error difference= 0.0006984878034472786
# error difference= 0.0006961884390506157
# error difference= 0.0006938966442930905
# error difference= 0.0006916123936449026
# error difference= 0.0006893356629475988
# error difference= 0.00068706642685612
# error difference= 0.0006848046608922687
# obj function after every 10 iterations: 0.4377991713363095
# error difference= 0.0006825503405778477
# error difference= 0.0006803034410012287
# error difference= 0.0006780639386363418
# error difference= 0.0006758318077260128
# error difference= 0.0006736070254405035
# error difference= 0.0006713895665129144
# error difference= 0.0006691794075237567
# error difference= 0.0006669765246627435
# error difference= 0.0006647808925066556
# error difference= 0.0006625924889789303
# obj function after every 10 iterations: 0.42894465616534666
# error difference= 0.0006604112888624059
# error difference= 0.0006582372696328775
# error difference= 0.0006560704069542567
# error difference= 0.000653910677762326
# error difference= 0.0006517580569180836
# error difference= 0.0006496125238655281
# error difference= 0.0006474740527053768
# error difference= 0.0006453426220005554
# error difference= 0.0006432182070028603
# error difference= 0.0006411007859341566
# obj function after every 10 iterations: 0.4204634491827196
# error difference= 0.0006389903350907389
# error difference= 0.0006368868316073417
# error difference= 0.0006347902527821248
# error difference= 0.0006327005757995607
# error difference= 0.0006306177776025379
# error difference= 0.000628541836007912
# error difference= 0.0006264727282214722
# error difference= 0.000624410431676381
# error difference= 0.000622354924317392
# error difference= 0.0006203061829594958
# obj function after every 10 iterations: 0.4123379466637934
# error difference= 0.0006182641862935156
# error difference= 0.0006162289117597197
# error difference= 0.0006142003367415327
# error difference= 0.0006121784404413688
# error difference= 0.0006101631994610557
# error difference= 0.0006081545925695764
# error difference= 0.000606152597555365
# error difference= 0.0006041571934360945
# error difference= 0.0006021683580925696
# error difference= 0.0006001860693558569
# obj function after every 10 iterations: 0.404551466575319
# error difference= 0.000598210306336
# error difference= 0.0005962410472690749
# error difference= 0.0005942782715067096
# error difference= 0.0005923219559562654
# error difference= 0.0005903720813833502
# error difference= 0.0005884286250221749
# error difference= 0.000586491566615166
# error difference= 0.0005845608846826167
# error difference= 0.000582636558874583
# error difference= 0.0005807185669510773
# obj function after every 10 iterations: 0.39708819629671155
# error difference= 0.0005788068898766596
# error difference= 0.0005769015047931703
# error difference= 0.0005750023934112392
# error difference= 0.0005731095325529623
# error difference= 0.0005712229035381711
# error difference= 0.0005693424848161044
# error difference= 0.00056746825606524
# error difference= 0.0005656001975324898
# error difference= 0.0005637382887471176
# error difference= 0.0005618825083502088
# obj function after every 10 iterations: 0.3899331434664471
# error difference= 0.0005600328381376585
# error difference= 0.0005581892558481627
# error difference= 0.0005563517429436615
# error difference= 0.0005545202792589521
# error difference= 0.0005526948439893431
# error difference= 0.0005508754181420272
# error difference= 0.0005490619818289133
# error difference= 0.0005472545152542807
# error difference= 0.0005454529985016165
# error difference= 0.0005436574121588933
# obj function after every 10 iterations: 0.38307208976143275
# error difference= 0.0005418677370485625
# error difference= 0.000540083953033843
# error difference= 0.0005383060413493013
# error difference= 0.0005365339822702708
# error difference= 0.0005347677569247367
# error difference= 0.0005330073452682882
# error difference= 0.0005312527292389291
# error difference= 0.000529503889261207
# error difference= 0.0005277608060154648
# error difference= 0.0005260234610915404
# obj function after every 10 iterations: 0.376491547426746
# error difference= 0.0005242918352550419
# error difference= 0.0005225659098115898
# error difference= 0.000520845666052594
# error difference= 0.0005191310850563013
# error difference= 0.0005174221484622876
# error difference= 0.0005157188373559052
# error difference= 0.0005140211337320011
# error difference= 0.0005123290185125029
# error difference= 0.000510642473614098
# error difference= 0.0005089614809321574
# obj function after every 10 iterations: 0.37017871838604766
# error difference= 0.0005072860216017716
# error difference= 0.0005056160779446373
# error difference= 0.0005039516317069115
# error difference= 0.000502292664378956
# error difference= 0.0005006391583819436
# error difference= 0.0004989910955686128
# error difference= 0.0004973484583601362
# error difference= 0.0004957112281402942
# error difference= 0.0004940793875931604
# error difference= 0.0004924529193104377
# obj function after every 10 iterations: 0.3641214557768264
# error difference= 0.0004908318046759064
# error difference= 0.0004892160270912882
# error difference= 0.00048760556830274027
# error difference= 0.00048600041105828495
# error difference= 0.00048440053771514613
# error difference= 0.0004828059311137167
# error difference= 0.00048121657414412766
# error difference= 0.0004796324484814818
# error difference= 0.0004780535383588358
# error difference= 0.00047647982564313907
# obj function after every 10 iterations: 0.3583082277606023
# error difference= 0.00047491129320320624
# error difference= 0.00047334792473208154
# error difference= 0.00047178970217487404
# error difference= 0.00047023660963674274
# error difference= 0.0004686886293114867
# error difference= 0.00046714574526163233
# error difference= 0.00046560794008598805
# error difference= 0.000464075196994429
# error difference= 0.0004625474997581591
# error difference= 0.0004610248316794241
# obj function after every 10 iterations: 0.3527280834667983
# error difference= 0.0004595071759396774
# error difference= 0.00045799451634565
# error difference= 0.0004564868361818242
# error difference= 0.0004549841191803239
# error difference= 0.0004534863490910368
# error difference= 0.00045199350942937144
# error difference= 0.00045050558405534957
# error difference= 0.0004490225570528139
# error difference= 0.00044754441175243187
# error difference= 0.00044607113267858267
# obj function after every 10 iterations: 0.3473706209443369
# error difference= 0.0004446027028421895
# error difference= 0.0004431391079968705
# error difference= 0.000441680330357741
# error difference= 0.00044022635541196564
# error difference= 0.000438777166326787
# error difference= 0.000437332748411734
# error difference= 0.0004358930849690523
# error difference= 0.0004344581609814213
# error difference= 0.0004330279604403131
# error difference= 0.00043160246803353175
# obj function after every 10 iterations: 0.3422259569938943
# error difference= 0.00043018166869757124
# error difference= 0.0004287655461858719
# error difference= 0.0004273540850654456
# error difference= 0.00042594727074884986
# error difference= 0.0004245450879061252
# error difference= 0.00042314752020189417
# error difference= 0.0004217545537699152
# error difference= 0.0004203661723884977
# error difference= 0.0004189823615199373
# error difference= 0.0004176031064311303
# obj function after every 10 iterations: 0.3372846987651921
# error difference= 0.00041622839143684587
# error difference= 0.0004148582020526703
# error difference= 0.00041349252290245886
# error difference= 0.0004121313397007498
# error difference= 0.0004107746374160115
# error difference= 0.00040942240126895513
# error difference= 0.0004080746163950266
# error difference= 0.00040673126844481544
# error difference= 0.0004053923428770645
# error difference= 0.0004040578247668236
# obj function after every 10 iterations: 0.3325379170204932
# error difference= 0.00040272769963678456
# error difference= 0.00040140195322635464
# error difference= 0.0004000805712998101
# error difference= 0.00039876353911338924
# error difference= 0.00039745084236386674
# error difference= 0.0003961424671317104
# error difference= 0.00039483839876197635
# error difference= 0.0003935386235021099
# error difference= 0.0003922431267788795
# error difference= 0.00039095189459104063
# obj function after every 10 iterations: 0.32797712095079434
# error difference= 0.0003896649131860386
# error difference= 0.00038838216864434116
# error difference= 0.00038710364682970066
# error difference= 0.00038582933334296854
# error difference= 0.0003845592150959476
# error difference= 0.0003832932779985754
# error difference= 0.00038203150801763286
# error difference= 0.00038077389165280806
# error difference= 0.00037952041580169293
# error difference= 0.0003782710660296118
# obj function after every 10 iterations: 0.3235942344588527
# error difference= 0.000377025828608879
# error difference= 0.0003757846905649842
# error difference= 0.0003745476388949953
# error difference= 0.00037331465861711877
# error difference= 0.00037208573778002574
# error difference= 0.00037086086221194137
# error difference= 0.0003696400188388793
# error difference= 0.0003684231944518501
# error difference= 0.00036721037573883564
# error difference= 0.00036600154947663555
# obj function after every 10 iterations: 0.3193815738178708
# error difference= 0.00036479670260192165
# error difference= 0.00036359582178846495
# error difference= 0.00036239889470479625
# error difference= 0.00036120590740296166
# error difference= 0.00036001684720687877
# error difference= 0.000358831701529283
# error difference= 0.0003576504572073702
# error difference= 0.000356473101241761
# error difference= 0.00035529962166336304
# error difference= 0.0003541300044531681
# obj function after every 10 iterations: 0.31533182662066545
# error difference= 0.0003529642377131381
# error difference= 0.00035180230868903095
# error difference= 0.0003506442043885727
# error difference= 0.0003494899124412143
# error difference= 0.000348339420870758
# error difference= 0.0003471927160383359
# error difference= 0.0003460497865503953
# error difference= 0.00034491061893859865
# error difference= 0.00034377520181294585
# error difference= 0.00034264352211721416
# obj function after every 10 iterations: 0.3114380319445817
# error difference= 0.00034151556803152516
# error difference= 0.0003403913270751957
# error difference= 0.0003392707867604372
# error difference= 0.00033815393513947356
# error difference= 0.0003370407606553272
# error difference= 0.0003359312501842737
# error difference= 0.0003348253925317124
# error difference= 0.0003337231746058933
# error difference= 0.0003326245856456467
# error difference= 0.0003315296128043599
# obj function after every 10 iterations: 0.30769356165610257
# error difference= 0.000330438244901643
# error difference= 0.00032935046955273606
# error difference= 0.0003282662747778886
# error difference= 0.0003271856495281611
# error difference= 0.0003261085811345765
# error difference= 0.00032503505867964577
# error difference= 0.00032396507016585474
# error difference= 0.00032289860377687774
# error difference= 0.00032183564836429923
# error difference= 0.00032077619193415785
# obj function after every 10 iterations: 0.30409210278694027
# error difference= 0.00031972022338422335
# error difference= 0.0003186677307418506
# error difference= 0.00031761870243940393
# error difference= 0.0003165731283978346
# error difference= 0.00031553099584158417
# error difference= 0.000314492293711055
# error difference= 0.00031345701070861764
# error difference= 0.00031242513687246287
# error difference= 0.0003113966584642469
# error difference= 0.00031037156638902275
# obj function after every 10 iterations: 0.3006276409189213
# error difference= 0.0003093498491928415
# error difference= 0.000308331494828451
# error difference= 0.0003073164931279848
# error difference= 0.0003063048324065676
# error difference= 0.0003052965024501475
# error difference= 0.00030429149138910816
# error difference= 0.0003032897890484776
# error difference= 0.0003022913840027286
# error difference= 0.0003012962657429341
# error difference= 0.0003003044231633112
# obj function after every 10 iterations: 0.2972944445142058
# error difference= 0.000299315846049808
# error difference= 0.00029833052308703145
# error difference= 0.00029734844333262345
# error difference= 0.0002963695969242508
# error difference= 0.00029539397280586854
# error difference= 0.00029442156000669684
# error difference= 0.00029345234881006377
# error difference= 0.0002924863277513623
# error difference= 0.0002915234867799654
# error difference= 0.00029056381587011515
# obj function after every 10 iterations: 0.29408705013740244
# error difference= 0.00028960730342930674
# error difference= 0.00028865394040522574
# error difference= 0.0002877037153119488
# error difference= 0.00028675661826937926
# error difference= 0.00028581263963900483
# error difference= 0.0002848717677963464
# error difference= 0.0002839339932130258
# error difference= 0.00028299930612618596
# error difference= 0.0002820676958918966
# error difference= 0.0002811391523067641
# obj function after every 10 iterations: 0.2910002485137717
# error difference= 0.0002802136651709475
# error difference= 0.00027929122521896943
# error difference= 0.0002783718214267594
# error difference= 0.00027745544447199677
# error difference= 0.00027654208403760094
# error difference= 0.0002756317303678202
# error difference= 0.00027472437324149723
# error difference= 0.0002738200035494742
# error difference= 0.00027291861074374424
# error difference= 0.00027202018509697723
# obj function after every 10 iterations: 0.28802907137349293
# error difference= 0.000271124717020399
# error difference= 0.00027023219689681355
# error difference= 0.00026934261472177923
# error difference= 0.00026845596144298156
# error difference= 0.0002675722260825353
# error difference= 0.00026669140050117335
# error difference= 0.0002658134746624796
# error difference= 0.00026493843894570546
# error difference= 0.0002640662828632401
# error difference= 0.00026319699864529866
# obj function after every 10 iterations: 0.285168779038427
# error difference= 0.00026233057596414255
# error difference= 0.0002614670054867929
# error difference= 0.00026060627747170884
# error difference= 0.0002597483833142178
# error difference= 0.0002588933128926385
# error difference= 0.00025804105752413875
# error difference= 0.0002571916077158676
# error difference= 0.0002563449541206353
# error difference= 0.00025550108781757785
# error difference= 0.00025465999909002335
# obj function after every 10 iterations: 0.28241484870171246
# error difference= 0.00025382167995502414
# error difference= 0.00025298611938140425
# error difference= 0.0002521533102850526
# error difference= 0.0002513232420682243
# error difference= 0.00025049590698245083
# error difference= 0.0002496712952009261
# error difference= 0.0002488493977850226
# error difference= 0.0002480302060341444
# error difference= 0.00024721371116598334
# error difference= 0.0002463999039505893
# obj function after every 10 iterations: 0.2797629633655865
# error difference= 0.000245588775904082
# error difference= 0.0002447803181269137
# error difference= 0.0002439745214850575
# error difference= 0.00024317137725660132
# error difference= 0.00024237087727385642
# error difference= 0.00024157301228200367
# error difference= 0.00024077777409203804
# error difference= 0.00023998515340650783
# error difference= 0.00023919514186587776
# error difference= 0.00023840773155825445
# obj function after every 10 iterations: 0.27720900139301846
# error difference= 0.00023762291284867842
# error difference= 0.0002368406778501253
# error difference= 0.00023606101792594814
# error difference= 0.00023528392456029223
# error difference= 0.00023450938920177578
# error difference= 0.00023373740367560458
# error difference= 0.0002329679596577705
# error difference= 0.00023220104821319865
# error difference= 0.00023143666133051966
# error difference= 0.00023067479130034485
# obj function after every 10 iterations: 0.27474902663989437
# error difference= 0.000229915428683114
# error difference= 0.00022915856638405785
# error difference= 0.00022840419514125188
# error difference= 0.0002276523073767578
# error difference= 0.00022690289453564105
# error difference= 0.00022615594915720294
# error difference= 0.0002254114625301895
# error difference= 0.00022466942668586398
# error difference= 0.00022392983322916393
# error difference= 0.00022319267482728833
# obj function after every 10 iterations: 0.27237927913132576
# error difference= 0.00022245794316688716
# error difference= 0.00022172562960065534
# error difference= 0.0002209957271759322
# error difference= 0.00022026822766108012
# error difference= 0.00021954312294170109
# error difference= 0.00021882040498866218
# error difference= 0.00021810006633771195
# error difference= 0.00021738209885313609
# error difference= 0.00021666649480422961
# error difference= 0.00021595324686884965
# obj function after every 10 iterations: 0.2700961662532149
# error difference= 0.00021524234657732677
# error difference= 0.00021453378616342889
# error difference= 0.00021382755922871866
# error difference= 0.0002131236562235017
# error difference= 0.00021242207065697016
# error difference= 0.00021172279469539035
# error difference= 0.00021102582126175662
# error difference= 0.00021033114141744136
# error difference= 0.00020963874831991802
# error difference= 0.0002089486351088965
# obj function after every 10 iterations: 0.2678962544262778
# error difference= 0.00020826079371616402
# error difference= 0.00020757521624048536
# error difference= 0.0002068918955089316
# error difference= 0.00020621082481397934
# error difference= 0.00020553199553319246
# error difference= 0.00020485540150261272
# error difference= 0.00020418103409980404
# error difference= 0.00020350888709685933
# error difference= 0.00020283895264938678
# error difference= 0.00020217122363419548
# obj function after every 10 iterations: 0.2657762612335452
# error difference= 0.00020150569253374329
# error difference= 0.0002008423526476122
# error difference= 0.0002001811959040367
# error difference= 0.00019952221635932688
# error difference= 0.00019886540535907216
# error difference= 0.00019821075663628562
# error difference= 0.0001975582638600315
# error difference= 0.00019690791787496664
# error difference= 0.00019625971359715777
# error difference= 0.00019561364251785562
# obj function after every 10 iterations: 0.26373304798032354
# error difference= 0.00019496969865784308
# error difference= 0.00019432787462037027
# error difference= 0.0001936881631934284
# error difference= 0.0001930505578293662
# error difference= 0.0001924150512735423
# error difference= 0.00019178163667632475
# error difference= 0.0001911503077671739
# error difference= 0.0001905210562718196
# error difference= 0.00018989387713475026
# error difference= 0.00018926876177616236
# obj function after every 10 iterations: 0.2617636126525112
# error difference= 0.00018864570461829544
# error difference= 0.00018802469895007334
# error difference= 0.00018740573710118724
# error difference= 0.00018678881249911683
# error difference= 0.00018617391925346283
# error difference= 0.00018556105049327698
# error difference= 0.00018495019833864035
# error difference= 0.00018434135782996464
# error difference= 0.00018373452132891543
# error difference= 0.0001831296822274453
# obj function after every 10 iterations: 0.25986508325895336
# error difference= 0.0001825268347275255
# error difference= 0.00018192597123345422
# error difference= 0.0001813270860218097
# error difference= 0.0001807301723317778
# error difference= 0.00018013522349136224
# error difference= 0.00017954223301330785
# error difference= 0.00017895119501432077
# error difference= 0.0001783621024245008
# error difference= 0.00017777494900172996
# error difference= 0.00017718972872771133
# obj function after every 10 iterations: 0.2580347115294064
# error difference= 0.00017660643462846792
# error difference= 0.00017602506096991988
# error difference= 0.00017544560077453752
# error difference= 0.0001748680485178511
# error difference= 0.00017429239733246504
# error difference= 0.00017371864108639556
# error difference= 0.0001731467738679271
# error difference= 0.00017257678869597726
# error difference= 0.00017200868034805694
# error difference= 0.0001714424418786109
# obj function after every 10 iterations: 0.2562698669520238
# error difference= 0.00017087806759263913
# error difference= 0.00017031555096380657
# error difference= 0.0001697548862900078
# error difference= 0.00016919606736465198
# error difference= 0.00016863908761877155
# error difference= 0.0001680839419577751
# error difference= 0.00016753062347873993
# error difference= 0.00016697912626284506
# error difference= 0.00016642944489575484
# error difference= 0.00016588157295416295
# obj function after every 10 iterations: 0.2545680311263818
# error difference= 0.00016533550442332512
# error difference= 0.00016479123374324445
# error difference= 0.00016424875440534947
# error difference= 0.00016370806118004566
# error difference= 0.00016316914772218638
# error difference= 0.00016263200852506543
# error difference= 0.00016209663720445633
# error difference= 0.00016156302864445138
# error difference= 0.0001610311761979233
# error difference= 0.0001605010750971303
# obj function after every 10 iterations: 0.25292679241786625
# error difference= 0.00015997271879086838
# error difference= 0.00015944610164808637
# error difference= 0.00015892121818339433
# error difference= 0.00015839806291850778
# error difference= 0.00015787662953314907
# error difference= 0.00015735691260587714
# error difference= 0.00015683890671880363
# error difference= 0.00015632260593179126
# error difference= 0.00015580800486603152
# error difference= 0.00015529509786915696
# obj function after every 10 iterations: 0.2513438408943943
# error difference= 0.00015478387906142643
# error difference= 0.00015427434323100897
# error difference= 0.0001537664851873899
# error difference= 0.00015326029842910316
# error difference= 0.0001527557781564326
# error difference= 0.00015225291883069758
# error difference= 0.0001517517146041314
# error difference= 0.00015125216070188685
# error difference= 0.00015075425087118788
# error difference= 0.00015025798032652915
# obj function after every 10 iterations: 0.2498169635287264
# error difference= 0.00014976334371397115
# error difference= 0.0001492703350898239
# error difference= 0.00014877894932396885
# error difference= 0.000148289181279182
# error difference= 0.00014780102572231613
# error difference= 0.00014731447684468435
# error difference= 0.0001468295297684108
# error difference= 0.00014634617893349855
# error difference= 0.0001458644196361547
# error difference= 0.00014538424603571798
# obj function after every 10 iterations: 0.24834403965217056
# error difference= 0.0001449056530518078
# error difference= 0.00014442863540509165
# error difference= 0.0001439531885445433
# error difference= 0.00014347930621028127
# error difference= 0.00014300698444458249
# error difference= 0.0001425362172327027
# error difference= 0.0001420669997074242
# error difference= 0.0001415993268381044
# error difference= 0.00014113319367581312
# error difference= 0.00014066859468542248
# obj function after every 10 iterations: 0.24692303664707604
# error difference= 0.00014020552556814891
# error difference= 0.0001397439800854272
# error difference= 0.00013928395494033907
# error difference= 0.00013882544344667735
# error difference= 0.0001383684415117159
# error difference= 0.00013791294400888887
# error difference= 0.0001374589461953235
# error difference= 0.00013700644257497174
# error difference= 0.00013655542874246862
# error difference= 0.00013610589915913351
# obj function after every 10 iterations: 0.24555200585950254
# error difference= 0.00013565785016922405
# error difference= 0.00013521127556970214
# error difference= 0.0001347661713353432
# error difference= 0.0001343225320908914
# error difference= 0.0001338803534309818
# error difference= 0.00013343963064116338
# error difference= 0.0001330003580903849
# error difference= 0.00013256253204119162
# error difference= 0.00013212614704372072
# error difference= 0.00013169119868905454
# obj function after every 10 iterations: 0.24422907872592253
# error difference= 0.00013125768229826917
# error difference= 0.00013082559260269022
# error difference= 0.0001303949256836745
# error difference= 0.00012996567622280963
# error difference= 0.0001295378399781555
# error difference= 0.0001291114122317083
# error difference= 0.00012868638804874877
# error difference= 0.0001282627631198352
# error difference= 0.00012784053271275297
# error difference= 0.00012741969229423944
# obj function after every 10 iterations: 0.24295246309789542
# error difference= 0.00012700023695089158
# error difference= 0.00012658216285998947
# error difference= 0.0001261654647706223
# error difference= 0.00012575013852611505
# error difference= 0.0001253361794404384
# error difference= 0.00012492358296967154
# error difference= 0.00012451234498556119
# error difference= 0.00012410246065641672
# error difference= 0.00012369392553068792
# error difference= 0.0001232867352030098
# obj function after every 10 iterations: 0.24172043975450064
# error difference= 0.00012288088566236866
# error difference= 0.000122476371963387
# error difference= 0.0001220731896687255
# error difference= 0.00012167133493790061
# error difference= 0.00012127080300317061
# error difference= 0.0001208715894236434
# error difference= 0.00012047369017764709
# error difference= 0.00012007710073191902
# error difference= 0.00011968181668464695
# error difference= 0.00011928783407455512
# obj function after every 10 iterations: 0.240531359091872
# error difference= 0.00011889514842877702
# error difference= 0.0001185037555018198
# error difference= 0.00011811365079950065
# error difference= 0.00011772483054528493
# error difference= 0.0001173372901277503
# error difference= 0.0001169510253298256
# error difference= 0.00011656603228971107
# error difference= 0.00011618230664112161
# error difference= 0.00011579984378684571
# error difference= 0.00011541864039799066
# obj function after every 10 iterations: 0.23938363798224085
# error difference= 0.00011503869187379223
# error difference= 0.00011465999388704518
# error difference= 0.00011428254275713812
# error difference= 0.00011390633401120454
# error difference= 0.00011353136381941908
# error difference= 0.00011315762781549665
# error difference= 0.00011278512220513903
# error difference= 0.0001124138431372046
# error difference= 0.00011204378598250742
# error difference= 0.00011167494683306245
# obj function after every 10 iterations: 0.23827575678908258
# error difference= 0.00011130732239550412
# error difference= 0.00011094090780616739
# error difference= 0.00011057569956207658
# error difference= 0.0001102116934319497
# error difference= 0.00010984888560727768
# error difference= 0.00010948727215165377
# error difference= 0.00010912684914643478
# error difference= 0.00010876761256994882
# error difference= 0.00010840955842894573
# error difference= 0.00010805268320979167
# obj function after every 10 iterations: 0.23720625653323543
# error difference= 0.00010769698269186279
# error difference= 0.00010734245327270742
# error difference= 0.00010698909069262186
# error difference= 0.00010663689131718002
# error difference= 0.00010628585145511238
# error difference= 0.0001059359673796223
# error difference= 0.0001055872348629805
# error difference= 0.00010523965046616013
# error difference= 0.00010489320992590478
# error difference= 0.00010454791052794121
# obj function after every 10 iterations: 0.23617373619996004
# error difference= 0.00010420374726294312
# error difference= 0.00010386071724965973
# error difference= 0.00010351881616443848
# error difference= 0.00010317804078141535
# error difference= 0.00010283838724944872
# error difference= 0.00010249985194832334
# error difference= 0.00010216243060057195
# error difference= 0.00010182612050257944
# error difference= 0.00010149091714950487
# error difference= 0.00010115681760680673
# obj function after every 10 iterations: 0.23517685017981874
# error difference= 0.00010082381762899217
# error difference= 0.00010049191392624834
# error difference= 0.00010016110294586156
# error difference= 9.983138075853049e-05
# error_diff after error is less than 0.0001: 9.983138075853049e-05
# value of m: -0.013844258578693721
# value of c: 30.584724409307448
# Number of iterations required: 1033

# %% [markdown]
# #### Question 3 Answer Here
#
# Write your answer to the question in this box.
#
# By using co-ordinate descent method we are adjusting just one coordinate on each iteration.Therefore we require many iterations to reach to the minimum.

# %% [markdown]
# ## Multiple Input Solution with Linear Algebra
#
# You've now seen how slow it can be to perform a coordinate ascent on a system. Another approach to solving the system (which is not always possible, particularly in *non-linear* systems) is to go direct to the minimum. To do this we need to introduce *linear algebra*. We will represent all our errors and functions in the form of linear algebra.
#
# As we mentioned above, linear algebra is just a shorthand for performing lots of multiplications and additions simultaneously. What does it have to do with our system then? Well the first thing to note is that the linear function we were trying to fit has the following form:
# $$
# f(x) = mx + c
# $$
# the classical form for a straight line. From a linear algebraic perspective we are looking for multiplications and additions. We are also looking to separate our parameters from our data. The data is the *givens* remember, in French the word is données literally translated means *givens* that's great, because we don't need to change the data, what we need to change are the parameters (or variables) of the model. In this function the data comes in through $x$, and the parameters are $m$ and $c$.
#
# What we'd like to create is a vector of parameters and a vector of data. Then we could represent the system with vectors that represent the data, and vectors that represent the parameters.
#
# We look to turn the multiplications and additions into a linear algebraic form, we have one multiplication ($m\times c$) and one addition ($mx + c$). But we can turn this into a inner product by writing it in the following way,
# $$
# f(x) = m \times x + c \times 1,
# $$
# in other words we've extracted the unit value, from the offset, $c$. We can think of this unit value like an extra item of data, because it is always given to us, and it is always set to 1 (unlike regular data, which is likely to vary!). We can therefore write each input data location, $\mathbf{x}$, as a vector
# $$
# \mathbf{x} = \begin{bmatrix} 1\\ x\end{bmatrix}.
# $$
#
# Now we choose to also turn our parameters into a vector. The parameter vector will be defined to contain
# $$
# \mathbf{w} = \begin{bmatrix} c \\ m\end{bmatrix}
# $$
# because if we now take the inner product between these to vectors we recover
# $$
# \mathbf{x}\cdot\mathbf{w} = 1 \times c + x \times m = mx + c
# $$
# In `numpy` we can define this vector as follows

# %%
# define the vector w
w = np.zeros(shape=(2, 1))
w[0] = m
w[1] = c

# %% [markdown]
# This gives us the equivalence between original operation and an operation in vector space. Whilst the notation here isn't a lot shorter, the beauty is that we will be able to add as many features as we like and still keep the same representation. In general, we are now moving to a system where each of our predictions is given by an inner product. When we want to represent a linear product in linear algebra, we tend to do it with the transpose operation, so since we have $\mathbf{a}\cdot\mathbf{b} = \mathbf{a}^\top\mathbf{b}$ we can write
# $$
# f(\mathbf{x}_i) = \mathbf{x}_i^\top\mathbf{w}.
# $$
# Where we've assumed that each data point, $\mathbf{x}_i$, is now written by appending a 1 onto the original vector
# $$
# \mathbf{x}_i =
# \begin{bmatrix}
# 1 \\
# x_i
# \end{bmatrix}
# $$
#
# ## Design Matrix
#
# We can do this for the entire data set to form a [*design matrix*](http://en.wikipedia.org/wiki/Design_matrix) $\mathbf{X}$,
#
# $$\mathbf{X} = \begin{bmatrix}
# \mathbf{x}_1^\top \\\
# \mathbf{x}_2^\top \\\
# \vdots \\\
# \mathbf{x}_n^\top
# \end{bmatrix} = \begin{bmatrix}
# 1 & x_1 \\\
# 1 & x_2 \\\
# \vdots & \vdots \\\
# 1 & x_n
# \end{bmatrix},$$
#
# which in `numpy` can be done with the following commands:

# %%
X = np.hstack((np.ones_like(x), x))
print(X)
# Out:
# [[1.000e+00 1.896e+03]
#  [1.000e+00 1.900e+03]
#  [1.000e+00 1.904e+03]
#  [1.000e+00 1.908e+03]
#  [1.000e+00 1.912e+03]
#  [1.000e+00 1.920e+03]
#  [1.000e+00 1.924e+03]
#  [1.000e+00 1.928e+03]
#  [1.000e+00 1.932e+03]
#  [1.000e+00 1.936e+03]
#  [1.000e+00 1.948e+03]
#  [1.000e+00 1.952e+03]
#  [1.000e+00 1.956e+03]
#  [1.000e+00 1.960e+03]
#  [1.000e+00 1.964e+03]
#  [1.000e+00 1.968e+03]
#  [1.000e+00 1.972e+03]
#  [1.000e+00 1.976e+03]
#  [1.000e+00 1.980e+03]
#  [1.000e+00 1.984e+03]
#  [1.000e+00 1.988e+03]
#  [1.000e+00 1.992e+03]
#  [1.000e+00 1.996e+03]
#  [1.000e+00 2.000e+03]
#  [1.000e+00 2.004e+03]
#  [1.000e+00 2.008e+03]
#  [1.000e+00 2.012e+03]]

# %% [markdown]
# ### Writing the Objective with Linear Algebra
#
# When we think of the objective function, we can think of it as the errors where the error is defined in a similar way to what it was in Legendre's day $y_i - f(\mathbf{x}_i)$, in statistics these errors are also sometimes called [*residuals*](http://en.wikipedia.org/wiki/Errors_and_residuals_in_statistics). So we can think as the objective and the prediction function as two separate parts, first we have,
# $$
# E(\mathbf{w}) = \sum_{i=1}^n (y_i - f(\mathbf{x}_i; \mathbf{w}))^2,
# $$
# where we've made the function $f(\cdot)$'s dependence on the parameters $\mathbf{w}$ explicit in this equation. Then we have the definition of the function itself,
# $$
# f(\mathbf{x}_i; \mathbf{w}) = \mathbf{x}_i^\top \mathbf{w}.
# $$
# Let's look again at these two equations and see if we can identify any inner products. The first equation is a sum of squares, which is promising. Any sum of squares can be represented by an inner product,
# $$
# a = \sum_{i=1}^{k} b^2_i = \mathbf{b}^\top\mathbf{b},
# $$
# so if we wish to represent $E(\mathbf{w})$ in this way, all we need to do is convert the sum operator to an inner product. We can get a vector from that sum operator by placing both $y_i$ and $f(\mathbf{x}_i; \mathbf{w})$ into vectors, which we do by defining
# $$
# \mathbf{y} = \begin{bmatrix}y_1\\y_2\\ \vdots \\ y_n\end{bmatrix}
# $$
# and defining
# $$
# \mathbf{f}(\mathbf{X}; \mathbf{w}) = \begin{bmatrix}f(\mathbf{x}_1; \mathbf{w})\\f(\mathbf{x}_2; \mathbf{w})\\ \vdots \\ f(\mathbf{x}_n; \mathbf{w})\end{bmatrix}.
# $$
# The second of these is actually a vector-valued function. This term may appear intimidating, but the idea is straightforward. A vector valued function is simply a vector whose elements are themselves defined as *functions*, i.e. it is a vector of functions, rather than a vector of scalars. The idea is so straightforward, that we are going to ignore it for the moment, and barely use it in the derivation. But it will reappear later when we introduce *basis functions*. So we will, for the moment, ignore the dependence of $\mathbf{f}$ on $\mathbf{w}$ and $\mathbf{X}$ and simply summarise it by a vector of numbers
# $$
# \mathbf{f} = \begin{bmatrix}f_1\\f_2\\ \vdots \\ f_n\end{bmatrix}.
# $$
# This allows us to write our objective in the folowing, linear algebraic form,
# $$
# E(\mathbf{w}) = (\mathbf{y} - \mathbf{f})^\top(\mathbf{y} - \mathbf{f})
# $$
# from the rules of inner products.
#
# But what of our matrix $\mathbf{X}$ of input data? At this point, we need to dust off [*matrix-vector multiplication*](http://en.wikipedia.org/wiki/Matrix_multiplication). Matrix multiplication is simply a convenient way of performing many inner products together, and it's exactly what we need to summarise the operation
# $$
# f_i = \mathbf{x}_i^\top\mathbf{w}.
# $$
# This operation tells us that each element of the vector $\mathbf{f}$ (our vector valued function) is given by an inner product between $\mathbf{x}_i$ and $\mathbf{w}$. In other words it is a series of inner products. Let's look at the definition of matrix multiplication, it takes the form
# $$
# \mathbf{c} = \mathbf{B}\mathbf{a}
# $$
# where $\mathbf{c}$ might be a $k$ dimensional vector (which we can intepret as a $k\times 1$ dimensional matrix), and $\mathbf{B}$ is a $k\times k$ dimensional matrix and $\mathbf{a}$ is a $k$ dimensional vector ($k\times 1$ dimensional matrix).
#
# The result of this multiplication is of the form
# $$
# \begin{bmatrix}c_1\\c_2 \\ \vdots \\ a_k\end{bmatrix} =
# \begin{bmatrix} b_{1,1} & b_{1, 2} & \dots & b_{1, k} \\
# b_{2, 1} & b_{2, 2} & \dots & b_{2, k} \\
# \vdots & \vdots & \ddots & \vdots \\
# b_{k, 1} & b_{k, 2} & \dots & b_{k, k} \end{bmatrix} \begin{bmatrix}a_1\\a_2 \\ \vdots\\ c_k\end{bmatrix} = \begin{bmatrix} b_{1, 1}a_1 + b_{1, 2}a_2 + \dots + b_{1, k}a_k\\
# b_{2, 1}a_1 + b_{2, 2}a_2 + \dots + b_{2, k}a_k \\
# \vdots\\
# b_{k, 1}a_1 + b_{k, 2}a_2 + \dots + b_{k, k}a_k\end{bmatrix}
# $$
# so we see that each element of the result, $\mathbf{a}$ is simply the inner product between each *row* of $\mathbf{B}$ and the vector $\mathbf{c}$. Because we have defined each element of $\mathbf{f}$ to be given by the inner product between each *row* of the design matrix and the vector $\mathbf{w}$ we now can write the full operation in one matrix multiplication,
# $$
# \mathbf{f} = \mathbf{X}\mathbf{w}.
# $$

# %%
f = np.dot(X, w) # np.dot does matrix multiplication in python

# %% [markdown]
# Combining this result with our objective function,
# $$
# E(\mathbf{w}) = (\mathbf{y} - \mathbf{f})^\top(\mathbf{y} - \mathbf{f})
# $$
# we find we have defined the *model* with two equations. One equation tells us the form of our predictive function and how it depends on its parameters, the other tells us the form of our objective function.

# %%
resid = (y-f)
E = np.dot(resid.T, resid) # matrix multiplication on a single vector is equivalent to a dot product.
print("Error function is:", E)
# Out:
# Error function is: [[9.66795195e+10]]

# %% [markdown]
# ### Assignment Question 4
#
# The prediction for our movie recommender system had the form
# $$
# f_{i,j} = \mathbf{u}_i^\top \mathbf{v}_j
# $$
# and the objective function was then
# $$
# E = \sum_{i,j} s_{i,j}(y_{i,j} - f_{i, j})^2
# $$
# Try writing this down in matrix and vector form. How many of the terms can you do? For each variable and parameter carefully think about whether it should be represented as a matrix or vector. Do as many of the terms as you can. Use $\LaTeX$ to give your answers and give the *dimensions* of any matrices you create.
#
# *20 marks*

# %% [markdown]
# #### Question 4 Answer
#
# Write your answer to the question in this box.
#
# As we have to take inner product of $u_i$ and $v_i$, we will express it in terms of matix of vectors as follows,
#
# $$
# \mathbf{u_i} = \begin{bmatrix}u_{i,1}\\u_{i,2}\end{bmatrix}
# $$
#
# $$
# \mathbf{v_j} = \begin{bmatrix}v_{j,1}\\v_{j,2}\end{bmatrix}
# $$
#
# The prediction for our movie recommender system had the form
# $$
# f_{i,j} = \mathbf{u}_i^\top \mathbf{v}_j
# $$
#
# Taking transpose of $u_i$,
#
# $$
# \mathbf{u_i}^T = \begin{bmatrix}u_{i,1}\;u_{i,2}\end{bmatrix}
# $$
#
# Therefore,
#
# $$
# f_{i,j} = \begin{bmatrix}u_{i,1}\;u_{i,2}\end{bmatrix} \begin{bmatrix}v_{j,1}\\v_{j,2}\end{bmatrix}
# $$
#
# Now by using matrix multiplication, we get,
#
# $$
# f_{i,j} = u_{i,1}v_{j,1} + u_{i,2}v_{j,2}
# $$
#
# This represent the single term in the matrix. Now lets represent the entire F matrix in $nxm$ dimensions as follows,
#
# $$
# F=\begin{bmatrix} u_{1, 1}v_{1, 1} + u_{1, 2}v_{1, 2} & u_{1, 1}v_{2, 1} + u_{1, 2}v_{2, 2} & +\dots + &  u_{1, 1}v_{m, 1} + u_{1, 2}v_{m, 2}\\
# u_{2, 1}v_{1, 1} + u_{2, 2}v_{1, 2} & u_{2, 1}v_{2, 1} + u_{2, 2}v_{2, 2} & +\dots + &  u_{2, 1}v_{m, 1} + u_{2, 2}v_{m, 2}\\
# \vdots\\
# u_{n, 1}v_{1, 1} + u_{n, n}v_{1, 2} & u_{n, 1}v_{2, 1} + u_{n, n}v_{m, m} &  +\dots + & u_{n, 1}v_{m, 1} + u_{n, 2}v_{m, 2}\end{bmatrix}
# $$
#
# Similarly, Y is the matrix of dimension $nxm$ and can written as,
#
# $$
# Y=\begin{bmatrix} y_{1,1} & y_{1, 2} & \dots & y_{1, m} \\
# y_{2, 1} & y_{2, 2} & \dots & y_{2, m} \\
# \vdots & \vdots & \ddots & \vdots \\
# y_{n, 1} & y_{n, 2} & \dots & y_{n, m} \end{bmatrix}
# $$
#
# Now lets find $Y-F$ and $Y-F^T$
#
# $$
# Y-F=\begin{bmatrix} y_{1,1}-(u_{1, 1}v_{1, 1} + u_{1, 2}v_{1, 2}) & y_{1, 2}-(u_{1, 1}v_{2, 1} + u_{1, 2}v_{2, 2}) & +\dots + &  y_{1, m}-(u_{1, 1}v_{m, 1} + u_{1, 2}v_{m, 2})\\
# y_{2, 1}-(u_{2, 1}v_{1, 1} + u_{2, 2}v_{1, 2}) & y_{2, 2}-(u_{2, 1}v_{2, 1} + u_{2, 2}v_{2, 2}) & +\dots + &  y_{2, m}-(u_{2, 1}v_{m, 1} + u_{2, 2}v_{m, 2})\\
# \vdots\\
# y_{n, 1}-(u_{n, 1}v_{1, 1} + u_{n, n}v_{1, 2}) & y_{n, 2}- (u_{n, 1}v_{2, 1} + u_{n, n}v_{m, m}) &  +\dots + & y_{n, m}-(u_{n, 1}v_{m, 1} + u_{n, 2}v_{m, 2})\end{bmatrix}
# $$
#
# $$
# {Y-F}^T=\begin{bmatrix} y_{1,1}-(u_{1, 1}v_{1, 1} + u_{1, 2}v_{1, 2}) & y_{2, 1}-(u_{2, 1}v_{1, 1} + u_{2, 2}v_{1, 2}) & +\dots + &  y_{n, 1}-(u_{n, 1}v_{1, 1} + u_{n, n}v_{1, 2})\\
# y_{1, 2}-(u_{1, 1}v_{2, 1} + u_{1, 2}v_{2, 2}) & y_{2, 2}-(u_{2, 1}v_{2, 1} + u_{2, 2}v_{2, 2}) & +\dots + &  y_{n, 2}- (u_{n, 1}v_{2, 1} + u_{n, n}v_{m, m})\\
# \vdots\\
# y_{1, m}-(u_{1, 1}v_{m, 1} + u_{1, 2}v_{m, 2}) & y_{2, m}-(u_{2, 1}v_{m, 1} + u_{2, 2}v_{m, 2}) &  +\dots + & y_{n, m}-(u_{n, 1}v_{m, 1} + u_{n, 2}v_{m, 2})\end{bmatrix}
# $$
#
# We represent $E(w)$ as,
#
# $$
# E(w) = ({Y-F}^T)(Y-F)
# $$
#
# Therefore $E(w)$ will be the matrix of  $mxm$,
#
# $$
# E(w) =\begin{bmatrix} y_{1,1}-(u_{1, 1}v_{1, 1} + u_{1, 2}v_{1, 2}) & y_{2, 1}-(u_{2, 1}v_{1, 1} + u_{2, 2}v_{1, 2}) & +\dots + &  y_{n, 1}-(u_{n, 1}v_{1, 1} + u_{n, n}v_{1, 2})\\
# y_{1, 2}-(u_{1, 1}v_{2, 1} + u_{1, 2}v_{2, 2}) & y_{2, 2}-(u_{2, 1}v_{2, 1} + u_{2, 2}v_{2, 2}) & +\dots + &  y_{n, 2}- (u_{n, 1}v_{2, 1} + u_{n, n}v_{m, m})\\
# \vdots\\
# y_{1, m}-(u_{1, 1}v_{m, 1} + u_{1, 2}v_{m, 2}) & y_{2, m}-(u_{2, 1}v_{m, 1} + u_{2, 2}v_{m, 2}) &  +\dots + & y_{n, m}-(u_{n, 1}v_{m, 1} + u_{n, 2}v_{m, 2})\end{bmatrix}\\
# \begin{bmatrix} y_{1,1}-(u_{1, 1}v_{1, 1} + u_{1, 2}v_{1, 2}) & y_{1, 2}-(u_{1, 1}v_{2, 1} + u_{1, 2}v_{2, 2}) & +\dots + &  y_{1, m}-(u_{1, 1}v_{m, 1} + u_{1, 2}v_{m, 2})\\
# y_{2, 1}-(u_{2, 1}v_{1, 1} + u_{2, 2}v_{1, 2}) & y_{2, 2}-(u_{2, 1}v_{2, 1} + u_{2, 2}v_{2, 2}) & +\dots + &  y_{2, m}-(u_{2, 1}v_{m, 1} + u_{2, 2}v_{m, 2})\\
# \vdots\\
# y_{n, 1}-(u_{n, 1}v_{1, 1} + u_{n, n}v_{1, 2}) & y_{n, 2}- (u_{n, 1}v_{2, 1} + u_{n, n}v_{m, m}) &  +\dots + & y_{n, m}-(u_{n, 1}v_{m, 1} + u_{n, 2}v_{m, 2})\end{bmatrix}
# $$
#
# To simplify further, lets write $E(w)$ as F of matrix $mxm$
#
# $$
# E(w) =\mathbf{F}{i, j} = \begin{bmatrix} f_{1,1} & f_{1, 2} & \dots & f_{1, m} \\
# f_{2, 1} & f_{2, 2} & \dots & f_{2, m} \\
# \vdots & \vdots & \ddots & \vdots \\
# f_{m, 1} & f_{m, 2} & \dots & f_{m, m} \end{bmatrix}
# $$
#
#
# Now $S_{i,j}$ is matrix of $nxm$,
#
# $$
# \mathbf{S}{i, j} = \begin{bmatrix} s_{1,1} & s_{1, 2} & \dots & s_{1, m} \\
# s_{2, 1} & s_{2, 2} & \dots & s_{2, m} \\
# \vdots & \vdots & \ddots & \vdots \\
# s_{n, 1} & s_{n, 2} & \dots & s_{n, m} \end{bmatrix}
# $$
#
# Therefore E can be written as follows which is the matrix of dimension $nxm$
#
# $$
# E = \sum_{i,j} S_{i,j} F_{i, j}
# $$
#
# $$
# E = \sum_{i,j}\begin{bmatrix} s_{1,1} & s_{1, 2} & \dots & s_{1, m} \\
# s_{2, 1} & s_{2, 2} & \dots & s_{2, m} \\
# \vdots & \vdots & \ddots & \vdots \\
# s_{n, 1} & s_{n, 2} & \dots & s_{n, m} \end{bmatrix}
# \begin{bmatrix} f_{1,1} & f_{1, 2} & \dots & f_{1, m} \\
# f_{2, 1} & f_{2, 2} & \dots & f_{2, m} \\
# \vdots & \vdots & \ddots & \vdots \\
# f_{m, 1} & f_{m, 2} & \dots & f_{m, m} \end{bmatrix}
# $$
#
# By performing further matrix multiplication we get,
#
# $$
# E = \sum_{ij}\begin{bmatrix}
# s_{1,1}f_{1,1}+\dots+s_{1,m}f_{m,1} & \dots & s_{1,1}f_{m,1}+\dots+s_{1,m}f_{m,m}
# \\
# s_{2,1}f_{1,1}+\dots+s_{2,m}f_{m,2} & \dots & s_{2,1}f_{m,1}+\dots+s_{2,m}f_{m,m}
# \\
# \vdots & \ddots & \vdots
# \\
# s_{n,1}f_{1,1}+\dots+s_{n,m}f_{m,1} & \dots & s_{n,1}f_{1,m}+\dots+s_{n,m}f_{m,m}
# \end{bmatrix}$$

# %% [markdown]
# ## Objective Optimisation
#
# Our *model* has now been defined with two equations, the prediction function and the objective function. Next we will use multivariate calculus to define an *algorithm* to fit the model. The separation between model and algorithm is important and is often overlooked. Our model contains a function that shows how it will be used for prediction, and a function that describes the objective function we need to optimise to obtain a good set of parameters.
#
# The linear regression model we have described is still the same as the one we fitted above with a coordinate ascent algorithm. We have only played with the notation to obtain the same model in a matrix and vector notation. However, we will now fit this model with a different algorithm, one that is much faster. It is such a widely used algorithm that from the end user's perspective it doesn't even look like an algorithm, it just appears to be a single operation (or function). However, underneath the computer calls an algorithm to find the solution. Further, the algorithm we obtain is very widely used, and because of this it turns out to be highly optimised.
#
# Once again we are going to try and find the stationary points of our objective by finding the *stationary points*. However, the stationary points of a multivariate function, are a little bit more complext to find. Once again we need to find the point at which the derivative is zero, but now we need to use  *multivariate calculus* to find it. This involves learning a few additional rules of differentiation (that allow you to do the derivatives of a function with respect to  vector), but in the end it makes things quite a bit easier. We define vectorial derivatives as follows,
# $$
# \frac{\text{d}E(\mathbf{w})}{\text{d}\mathbf{w}} = \begin{bmatrix}\frac{\partial E(\mathbf{w})}{\partial w_1}\\\frac{\partial E(\mathbf{w})}{\partial w_2}\end{bmatrix}.
# $$
# where $\frac{\partial E(\mathbf{w})}{\partial w_1}$ is the [partial derivative](http://en.wikipedia.org/wiki/Partial_derivative) of the error function with respect to $w_1$.
#
# Differentiation through multiplications and additions is relatively straightforward, and since linear algebra is just multiplication and addition, then its rules of diffentiation are quite straightforward too, but slightly more complex than regular derivatives.
#
# ### Matrix Differentiation
#
# We will need two rules of differentiation. The first is diffentiation of an inner product. By remebering that the inner product is made up of multiplication and addition, we can hope that its derivative is quite straightforward, and so it proves to be. We can start by thinking about the definition of the inner product,
# $$
# \mathbf{a}^\top\mathbf{z} = \sum_{i} a_i z_i,
# $$
# which if we were to take the derivative with respect to $z_k$ would simply return the gradient of the one term in the sum for which the derivative was non zero, that of $a_k$, so we know that
# $$
# \frac{\text{d}}{\text{d}z_k} \mathbf{a}^\top \mathbf{z} = a_k
# $$
# and by our definition of multivariate derivatives we can simply stack all the partial derivatives of this form in a vector to obtain the result that
# $$
# \frac{\text{d}}{\text{d}\mathbf{z}} \mathbf{a}^\top \mathbf{z} = \mathbf{a}.
# $$
# The second rule that's required is differentiation of a 'matrix quadratic'. A scalar quadratic in $z$ with coefficient $c$ has the form $cz^2$. If $\mathbf{z}$ is a $k\times 1$ vector and $\mathbf{C}$ is a $k \times k$ *matrix* of coefficients then the matrix quadratic form is written as $\mathbf{z}^\top \mathbf{C}\mathbf{z}$, which is itself a *scalar* quantity, but it is a function of a *vector*.
#
# #### Matching Dimensions in Matrix Multiplications
#
# There's a trick for telling that it's a scalar result. When you are doing maths with matrices, it's always worth pausing to perform a quick sanity check on the dimensions. Matrix multplication only works when the dimensions match. To be precise, the 'inner' dimension of the matrix must match. What is the inner dimension. If we multiply two matrices $\mathbf{A}$ and $\mathbf{B}$, the first of which has $k$ rows and $\ell$ columns and the second of which has $p$ rows and $q$ columns, then we can check whether the multiplication works by writing the dimensionalities next to each other,
# $$
# \mathbf{A} \mathbf{B} \rightarrow (k \times \underbrace{\ell)(p}_\text{inner dimensions} \times q) \rightarrow (k\times q).
# $$
# The inner dimensions are the two inside dimensions, $\ell$ and $p$. The multiplication will only work if $\ell=p$. The result of the multiplication will then be a $k\times q$ matrix: this dimensionality comes from the 'outer dimensions'. Note that matrix multiplication is not [*commutative*](http://en.wikipedia.org/wiki/Commutative_property). And if you change the order of the multiplication,
# $$
# \mathbf{B} \mathbf{A} \rightarrow (\ell \times \underbrace{k)(q}_\text{inner dimensions} \times p) \rightarrow (\ell \times p).
# $$
# firstly it may no longer even work, because now the condition is that $k=q$, and secondly the result could be of a different dimensionality. An exception is if the matrices are square matrices (e.g. same number of rows as columns) and they are both *symmetric*. A symmetric matrix is one for which $\mathbf{A}=\mathbf{A}^\top$, or equivalently, $a_{i,j} = a_{j,i}$ for all $i$ and $j$.
#
# You will need to get used to working with matrices and vectors applying and developing new machine learning techniques. You should have come across them before, but you may not have used them as extensively as we will now do in this course. You should get used to using this trick to check your work and ensure you know what the dimension of an output matrix should be. For our matrix quadratic form, it turns out that we can see it as a special type of inner product.
# $$
# \mathbf{z}^\top\mathbf{C}\mathbf{z} \rightarrow (1\times \underbrace{k) (k}_\text{inner dimensions}\times k) (k\times 1) \rightarrow \mathbf{b}^\top\mathbf{z}
# $$
# where $\mathbf{b} = \mathbf{C}\mathbf{z}$ so therefore the result is a scalar,
# $$
# \mathbf{b}^\top\mathbf{z} \rightarrow (1\times \underbrace{k) (k}_\text{inner dimensions}\times 1) \rightarrow (1\times 1)
# $$
# where a $(1\times 1)$ matrix is recognised as a scalar.
#
# This implies that we should be able to differentiate this form, and indeed the rule for its differentiation is slightly more complex than the inner product, but still quite simple,
# $$
# \frac{\text{d}}{\text{d}\mathbf{z}} \mathbf{z}^\top\mathbf{C}\mathbf{z}= \mathbf{C}\mathbf{z} + \mathbf{C}^\top \mathbf{z}.
# $$
# Note that in the special case where $\mathbf{C}$ is symmetric then we have $\mathbf{C} = \mathbf{C}^\top$ and the derivative simplifies to
# $$
# \frac{\text{d}}{\text{d}\mathbf{z}} \mathbf{z}^\top\mathbf{C}\mathbf{z}= 2\mathbf{C}\mathbf{z}.
# $$
# ### Differentiating the Objective
#
# First, we need to compute the full objective by substituting our prediction function into the objective function to obtain the objective in terms of $\mathbf{w}$. Doing this we obtain
# $$
# E(\mathbf{w})= (\mathbf{y} - \mathbf{X}\mathbf{w})^\top (\mathbf{y} - \mathbf{X}\mathbf{w}).
# $$
# We now need to differentiate this *quadratic form* to find the minimum. We differentiate with respect to the *vector* $\mathbf{w}$. But before we do that, we'll expand the brackets in the quadratic form to obtain a series of scalar terms. The rules for bracket expansion across the vectors are similar to those for the scalar system giving,
# $$
# (\mathbf{a} - \mathbf{b})^\top (\mathbf{c} - \mathbf{d}) = \mathbf{a}^\top \mathbf{c} - \mathbf{a}^\top \mathbf{d} - \mathbf{b}^\top \mathbf{c} + \mathbf{b}^\top \mathbf{d}
# $$
# which substituting for $\mathbf{a} = \mathbf{c} = \mathbf{y}$ and $\mathbf{b}=\mathbf{d} = \mathbf{X}\mathbf{w}$ gives
# $$
# E(\mathbf{w})= \mathbf{y}^\top\mathbf{y} - 2\mathbf{y}^\top\mathbf{X}\mathbf{w} + \mathbf{w}^\top\mathbf{X}^\top\mathbf{X}\mathbf{w}
# $$
# where we used the fact that $\mathbf{y}^\top\mathbf{X}\mathbf{w}= \mathbf{w}^\top\mathbf{X}^\top\mathbf{y}$. Now we can use our rules of differentiation to compute the derivative of this form, which is,
# $$
# \frac{\text{d}}{\text{d}\mathbf{w}}E(\mathbf{w})=- 2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top\mathbf{X}\mathbf{w},
# $$
# where we have exploited the fact that $\mathbf{X}^\top\mathbf{X}$ is symmetric to obtain this result.

# %% [markdown]
# ### Assignment Question 5
#
# Use the equivalence between our vector and our matrix formulations of linear regression, alongside our definition of vector derivates, to match the gradients we've computed directly for $\frac{\text{d}E(c, m)}{\text{d}c}$ and $\frac{\text{d}E(c, m)}{\text{d}m}$ to those for $\frac{\text{d}E(\mathbf{w})}{\text{d}\mathbf{w}}$.
#
# *20 marks*

# %% [markdown]
# #### Question 5 Answer
#
# Write your answer to the question in this box.
#
# We have,
# $$
# \frac{\text{d}E(\mathbf{w})}{\text{d}w} = - 2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top\mathbf{X}\mathbf{w}
# $$
# or,$$
# \frac{\text{d}E(\mathbf{w})}{\text{d}w} =-  2(\mathbf{X}^\top \mathbf{y} - \mathbf{X}^\top\mathbf{X}\mathbf{w})
# $$
# Now,
#
# $$
# \mathbf{X} = \begin{bmatrix}
# 1 & x_1 \\\
# 1 & x_2 \\\
# 1 & x_3 \\\
# \vdots & \vdots \\\
# 1 & x_n
# \end{bmatrix}
# $$
#
# $$
# \mathbf{X}^\top = \begin{bmatrix}
# 1 & 1 & 1 & \dots & 1\\\
# x_1 & x_2 & x_3 & \dots & x_n \\\
# \end{bmatrix}
# $$
# $$
# \mathbf{y} = \begin{bmatrix}
# \mathbf{y}_1 \\\
# \mathbf{y}_2 \\\
# \mathbf{y}_3 \\\
# \vdots \\\
# \mathbf{y}_n
# \end{bmatrix}
# $$
#
# As we have to parameters, we can write matrix $w$ as,
#
# $$
# \mathbf{w} = \begin{bmatrix} c \\ m\end{bmatrix}
# $$
# $$
# \mathbf{X}^\top \mathbf{y} - \mathbf{X}^\top\mathbf{X}\mathbf{w} =  \begin{bmatrix}
# 1 & 1 & 1 & \dots & 1\\\
# x_1 & x_2 & x_3 & \dots & x_n \\\
# \end{bmatrix}\begin{bmatrix}
# \mathbf{y}_1 \\\
# \mathbf{y}_2 \\\
# \mathbf{y}_3 \\\
# \vdots \\\
# \mathbf{y}_n
# \end{bmatrix} - \begin{bmatrix}
# 1 & 1 & 1 & \dots & 1\\\
# x_1 & x_2 & x_3 & \dots & x_n \\\
# \end{bmatrix}\begin{bmatrix}
# 1 & x_1 \\\
# 1 & x_2 \\\
# 1 & x_3 \\\
# \vdots & \vdots \\\
# 1 & x_n
# \end{bmatrix}\begin{bmatrix} c \\ m\end{bmatrix}
# $$
#
# Now by matrix multiplication,
#
# $$
# \mathbf{X}^\top \mathbf{y} - \mathbf{X}^\top\mathbf{X}\mathbf{w} =
# \begin{bmatrix}y_1+y_2+y_3+y_4+ & \dots \ +y_n\\
# x_1y_1+x_2y_2+x_3y_3+ & \dots +x_ny_n\\\
# \end{bmatrix} - \begin{bmatrix}
# 1 & 1 & 1 & \dots & 1\\\
# x_1 & x_2 & x_3 & \dots & x_n \\\
# \end{bmatrix}\begin{bmatrix}
# c+mx_1 \\\
# c+mx_2 \\\
# c+mx_3 \\\
# \vdots\\\
# c+mx_n\end{bmatrix}
# $$
#
# $$
# \mathbf{X}^\top \mathbf{y} - \mathbf{X}^\top\mathbf{X}\mathbf{w} =
# \begin{bmatrix}y_1+y_2+y_3+y_4+ & \dots \ +y_n\\
# x_1y_1+x_2y_2+x_3y_3+ & \dots +x_ny_n\\\
# \end{bmatrix} - \begin{bmatrix}
# c+mx_1 + c+mx_2 + c+mx_3 +     \ \  \ \ \ \ \dots \ \ \ \ \ \ \ + c+mx_n\\\
# x(c+mx_1) + x(c+mx_2) + x(c+mx_3) + \dots + x(c+mx_n)\\\
# \end{bmatrix}
# $$
#
# $$
# \mathbf{X}^\top \mathbf{y} - \mathbf{X}^\top\mathbf{X}\mathbf{w} =
# \begin{bmatrix}y_1-(c+mx_1)+y_2-(c+mx_2)+y_3-(c+mx_3)+  \ \ \ \ \dots\ \ \ \ \ \ \ \ +y_n-(c+mx_n)\\
# x_1y_1-x_1(c+mx_1)+x_2y_2-x_2(c+mx_2)+x_3y_3-x_3(c+mx_3)+ \ \dots \ +x_ny_n-x_n(c+mx_n)\\\
# \end{bmatrix}
# $$
#
# Now, as
#
# $$
# \frac{\text{d}}{\text{d}\mathbf{w}}E(\mathbf{w}) = -2(\mathbf{X}^\top \mathbf{y} - \mathbf{X}^\top\mathbf{X}\mathbf{w})
# $$
#
# further substituiting the values, we get
#
# $$
# \therefore  \frac{\text{d}}{\text{d}\mathbf{w}}E(\mathbf{w}) = -2\begin{bmatrix}y_1-(c+mx_1)+y_2-(c+mx_2)+y_3-(c+mx_3)+  \ \ \ \ \dots\ \ \ \ \ \ \ \ +y_n-(c+mx_n)\\
# x_1y_1-x_1(c+mx_1)+x_2y_2-x_2(c+mx_2)+x_3y_3-x_3(c+mx_3)+ \ \dots \ +x_ny_n-x_n(c+mx_n)\\\
# \end{bmatrix}
# $$
# $$
# \therefore  \frac{\text{d}E(\mathbf{w})}{\text{d}m} = \begin{bmatrix}-\sum_{i=1}^n 2(y_i-mx_i-c) \\
# -\sum_{i=1}^n 2x_i(y_i-mx_i-c)\end{bmatrix}
# $$
#
#
#
# $$
# \therefore  \frac{\text{d}E(\mathbf{w})}{\text{d}m} = \begin{bmatrix}\frac{\text{d}E(c,m)}{\text{d}c} \\
# \frac{\text{d}E(c,m)}{\text{d}m}\end{bmatrix}
# $$
#
# Hence proved.

# %% [markdown]
# ## Update Equation for Global Optimum
#
# Once again, we need to find the minimum of our objective function. Using our likelihood for multiple input regression we can now minimize for our parameter vector $\mathbf{w}$. Firstly, just as in the single input case, we seek stationary points by finding parameter vectors that solve for when the gradients are zero,
# $$
# \mathbf{0}=- 2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top\mathbf{X}\mathbf{w},
# $$
# where $\mathbf{0}$ is a *vector* of zeros. Rearranging this equation we find the solution to be
# $$
# \mathbf{w} = \left[\mathbf{X}^\top \mathbf{X}\right]^{-1} \mathbf{X}^\top \mathbf{y}
# $$
# where $\mathbf{A}^{-1}$ denotes [*matrix inverse*](http://en.wikipedia.org/wiki/Invertible_matrix).
#
# ### Solving the Multivariate System
#
# The solution for $\mathbf{w}$ is given in terms of a matrix inverse, but computation of a matrix inverse requires, in itself, an algorithm to resolve it. You'll know this if you had to invert, by hand, a $3\times 3$ matrix in high school. From a numerical stability perspective, it is also best not to compute the matrix inverse directly, but rather to ask the computer to *solve* the  system of linear equations given by
# $$\mathbf{X}^\top\mathbf{X} \mathbf{w} = \mathbf{X}^\top\mathbf{y}$$
# for $\mathbf{w}$. This can be done in `numpy` using the command

# %%
np.linalg.solve?

# %% [markdown]
# so we can obtain the solution using

# %%
w = np.linalg.solve(np.dot(X.T, X), np.dot(X.T, y))
print(w)
# Out:
# [[ 2.88952457e+01]
#  [-1.29806477e-02]]

# %% [markdown]
# We can map it back to the liner regression and plot the fit as follows

# %%
m = w[1]; c=w[0]
f_test = m*x_test + c
print(m)
print(c)
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')
# Out:
# [-0.01298065]
# [28.89524574]

# %% [markdown]
# ## Multivariate Linear Regression
#
# A major advantage of the new system is that we can build a linear regression on a multivariate system. The matrix calculus didn't specify what the length of the vector $\mathbf{x}$ should be, or equivalently the size of the design matrix.
#
# ### Movie Body Count Data
#
# Let's load back in the movie body count data.

# %%
data = pods.datasets.movie_body_count()
movies = data['Y']
# Out:
# Acquiring resource: movie_body_count
#
# Details of data:
# Data scraped from www.MovieBodyCounts.com and www.imdb.com using scripts provided on a github repository (in both Python and R) at https://github.com/morpionZ/R-vs-Python/tree/master/Deadliest%20movies%20scrape/code. This script pulls down the scraped data.
#
# Please cite:
# Simon Garnier and Randy Olson, Blog Post: R vs Python Round 2, February 2nd 2014 (http://www.theswarmlab.com/r-vs-python-round-2-22/)
#
# After downloading the data will take up 536272 bytes of space.
#
# Data will be stored in /Users/sanika/ods_data_cache/movie_body_count.
#
# Do you wish to proceed with the download? [yes/no]
# yes
# Downloading  https://github.com/sjmgarnier/R-vs-Python/raw/master/Deadliest%20movies%20scrape/code/film-death-counts-Python.csv -> /Users/sanika/ods_data_cache/movie_body_count/film-death-counts-Python.csv
# [==============================]   0.366/0.366MB

# %% [markdown]
# Let's remind ourselves of the features we've been provided with.

# %%
print(', '.join(movies.columns))
# Out:
# Film, Year, Body_Count, MPAA_Rating, Genre, Director, Actors, Length_Minutes, IMDB_Rating

# %% [markdown]
# Now we will build a design matrix based on the numeric features: year, Body_Count, Length_Minutes in an effort to predict the rating. We build the design matrix as follows:
#
# ## Relation to Single Input System
#
# Bias as an additional feature.

# %%
select_features = ['Year', 'Body_Count', 'Length_Minutes']
X = movies.loc[:, select_features]
X['Eins'] = 1 # add a column for the offset
y = movies[['IMDB_Rating']]

# %% [markdown]
# Now let's perform a linear regression. But this time, we will create a pandas data frame for the result so we can store it in a form that we can visualise easily.

# %%
import pandas as pd
w = pd.DataFrame(data=np.linalg.solve(np.dot(X.T, X), np.dot(X.T, y)),  # solve linear regression here
                 index = X.columns,  # columns of X become rows of w
                 columns=['regression_coefficient']) # the column of X is the value of regression coefficient
w
# Out:
#                 regression_coefficient
# Year                         -0.016280
# Body_Count                   -0.000995
# Length_Minutes                0.025386
# Eins                         36.508363

# %% [markdown]
# We can check the residuals to see how good our estimates are

# %%
(y - np.dot(X, w)).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1815c62908>]],
#       dtype=object)

# %% [markdown]
# Which shows our model *hasn't* yet done a great job of representation, because the spread of values is large. We can check what the rating is dominated by in terms of regression coefficients.

# %%
w
# Out:
#                 regression_coefficient
# Year                         -0.016280
# Body_Count                   -0.000995
# Length_Minutes                0.025386
# Eins                         36.508363

# %% [markdown]
# Although we have to be a little careful about interpretation because our input values live on different scales, however it looks like we are dominated by the bias, with a small negative effect for later films (but bear in mind the years are large, so this effect is probably larger than it looks) and a positive effect for length. So it looks like long earlier films generally do better, but the residuals are so high that we probably haven't modelled the system very well.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ui-uNlFHoms')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('78YNphT90-k')

# %% [markdown]
# ## Solution with QR Decomposition
#
# Performing a solve instead of a matrix inverse is the more numerically stable approach, but we can do even better. A [QR-decomposition](http://en.wikipedia.org/wiki/QR_decomposition) of a matrix factorises it into a matrix which is an orthogonal matrix $\mathbf{Q}$, so that $\mathbf{Q}^\top \mathbf{Q} = \mathbf{I}$. And a matrix which is upper triangular, $\mathbf{R}$.
# $$
# \mathbf{X}^\top \mathbf{X} \boldsymbol{\beta} = \mathbf{X}^\top \mathbf{y}
# $$
# $$
# (\mathbf{Q}\mathbf{R})^\top (\mathbf{Q}\mathbf{R})\boldsymbol{\beta} = (\mathbf{Q}\mathbf{R})^\top \mathbf{y}
# $$
# $$
# \mathbf{R}^\top (\mathbf{Q}^\top \mathbf{Q}) \mathbf{R} \boldsymbol{\beta} = \mathbf{R}^\top \mathbf{Q}^\top \mathbf{y}
# $$
# $$
# \mathbf{R}^\top \mathbf{R} \boldsymbol{\beta} = \mathbf{R}^\top \mathbf{Q}^\top \mathbf{y}
# $$
# $$
# \mathbf{R} \boldsymbol{\beta} = \mathbf{Q}^\top \mathbf{y}
# $$
# This is a more numerically stable solution because it removes the need to compute $\mathbf{X}^\top\mathbf{X}$ as an intermediate. Computing $\mathbf{X}^\top\mathbf{X}$ is a bad idea because it involves squaring all the elements of $\mathbf{X}$ and thereby potentially reducing the numerical precision with which we can represent the solution. Operating on $\mathbf{X}$ directly preserves the numerical precision of the model.
#
# This can be more particularly seen when we begin to work with *basis functions* in the next week. Some systems that can be resolved with the QR decomposition can not be resolved by using solve directly.

# %%
import scipy as sp
Q, R = np.linalg.qr(X)
w = sp.linalg.solve_triangular(R, np.dot(Q.T, y)) 
w = pd.DataFrame(w, index=X.columns)
w
# Out:
#                         0
# Year            -0.016280
# Body_Count      -0.000995
# Length_Minutes   0.025386
# Eins            36.508363
